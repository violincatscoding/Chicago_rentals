# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
# import csv
# import json
#
#
# class ZillowScraper:
#     results = []
#
#     headers = {
#         'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
#         'accept-encoding': 'gzip, deflate, br',
#         'accept-language': 'en-US,en;q=0.9',
#         'cache-control': 'no-cache',
#         'cookie': 'zguid=23|%2403435e76-0699-4a32-b86d-77d033c907ef; _ga=GA1.2.1271511001.1575011821; zjs_user_id=null; zjs_anonymous_id=%2203435e76-0699-4a32-b86d-77d033c907ef%22; _gcl_au=1.1.1333357279.1575011822; _pxvid=3cfcc163-1278-11ea-bff8-0242ac12000b; ki_r=; __gads=ID=84d8013cfac6df96:T=1575012041:S=ALNI_MaSvVNZsir2JXJ17pv54bjsPuyfcw; ki_s=199442%3A0.0.0.0.0%3B199444%3A0.0.0.0.2; zgsession=1|c0999376-b167-4a47-a1cd-0e456d882d4e; _gid=GA1.2.55965867.1578668946; JSESSIONID=87D0662A6BC141A73F0D12620788519C; KruxPixel=true; DoubleClickSession=true; KruxAddition=true; ki_t=1575011869563%3B1578669044158%3B1578669044158%3B2%3B10; _pxff_tm=1; _px3=2e6809e35ce7e076934ff998c2bdb8140e8b793b53e08a27c5da11f1b4760755:DFItCmrETuS2OQcztcFmt0FYPUn00ihAAue2ynQgbfSq6H+p2yP3Rl3aeyls3Unr1VRJSgcNue8Rr1SUq4P1jA==:1000:9ueZvAJ6v5y4ny7psGF25dK+d3GlytY2Bh+Xj9UUhC4DaioIZ+FMXPU0mOX+Qnghqut0jIT61gLecN4fyu6qXaPDlBX6YsZVbIry1YyBN/37l0Ri3JP+E0h+m+QEBB+bqb6MbE2HtgGBJRJAry8dgOKGM5JtBGdX+X/nuQX1xaw=; AWSALB=E6JYC43gXQRlE2jPT9e2vAQOYPvdHnccBlqi0mcXevYExTaHro0M+uo/Qxahi6JyLz9LpotY9eLtEbYrAOeQXcCm6UhjWnTopQHernmjlR/ibE6JmE8F6tReiBn4; search=6|1581261153229%7Crect%3D40.96202658306895%252C-73.55498286718745%252C40.4487909557045%252C-74.40093013281245%26rid%3D6181%26disp%3Dmap%26mdm%3Dauto%26p%3D3%26z%3D0%26lt%3Dfsbo%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%09%01%096181%09%09%09%090%09US_%09',
#         'pragma': 'no-cache',
#         'upgrade-insecure-requests': '1',
#         'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/75.0.3770.142 Chrome/75.0.3770.142 Safari/537.36'
#     }
#
#     def fetch(self, url, params):
#         print('HTTP GET request to URL: %s' % url, end='')
#         res = requests.get(url, params=params, headers=self.headers)
#         print(' | Status code: %s' % res.status_code)
#
#         return res
#
#     def save_response(self, res):
#         with open('res.html', 'w') as html_file:
#             html_file.write(res)
#
#     def load_response(self):
#         html = ''
#
#         with open('res.html', 'r') as html_file:
#             for line in html_file:
#                 html += line
#
#         return html
#
#     def parse(self, html):
#         content = BeautifulSoup(html, 'lxml')
#         cards = content.findAll('article', {'class': 'list-card'})
#
#         for card in cards:
#             # try to extract image
#             try:
#                 image = card.find('div', {'class': 'list-card-top'}).find('img')['src']
#             except:
#                 image = 'N/A'
#
#             # extract items
#             items = {
#                 'url': card.find('a', {'class': 'list-card-link'})['href'],
#                 'details': [
#                             price.text for price in
#                             card.find('ul', {'class': 'list-card-details'}).find_all('li')
#                           ],
#                 'address': card.find('address', {'class': 'list-card-addr'}).text,
#                 'image': image
#             }
#
#             # try to extract price if not extracted yet
#             try:
#                 items['price'] = card.find('div', {'class': 'list-card-price'}).text
#             except:
#                 pass
#
#             # append scraped items to results list
#             self.results.append(items)
#             print(json.dumps(items, indent=2))

# %%
import requests
from bs4 import BeautifulSoup
import csv
import json


class ZillowScraper:
    results = []

    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.9',
        'cache-control': 'no-cache',
        'cookie': 'zguid=23|%2403435e76-0699-4a32-b86d-77d033c907ef; _ga=GA1.2.1271511001.1575011821; zjs_user_id=null; zjs_anonymous_id=%2203435e76-0699-4a32-b86d-77d033c907ef%22; _gcl_au=1.1.1333357279.1575011822; _pxvid=3cfcc163-1278-11ea-bff8-0242ac12000b; ki_r=; __gads=ID=84d8013cfac6df96:T=1575012041:S=ALNI_MaSvVNZsir2JXJ17pv54bjsPuyfcw; ki_s=199442%3A0.0.0.0.0%3B199444%3A0.0.0.0.2; zgsession=1|c0999376-b167-4a47-a1cd-0e456d882d4e; _gid=GA1.2.55965867.1578668946; JSESSIONID=87D0662A6BC141A73F0D12620788519C; KruxPixel=true; DoubleClickSession=true; KruxAddition=true; ki_t=1575011869563%3B1578669044158%3B1578669044158%3B2%3B10; _pxff_tm=1; _px3=2e6809e35ce7e076934ff998c2bdb8140e8b793b53e08a27c5da11f1b4760755:DFItCmrETuS2OQcztcFmt0FYPUn00ihAAue2ynQgbfSq6H+p2yP3Rl3aeyls3Unr1VRJSgcNue8Rr1SUq4P1jA==:1000:9ueZvAJ6v5y4ny7psGF25dK+d3GlytY2Bh+Xj9UUhC4DaioIZ+FMXPU0mOX+Qnghqut0jIT61gLecN4fyu6qXaPDlBX6YsZVbIry1YyBN/37l0Ri3JP+E0h+m+QEBB+bqb6MbE2HtgGBJRJAry8dgOKGM5JtBGdX+X/nuQX1xaw=; AWSALB=E6JYC43gXQRlE2jPT9e2vAQOYPvdHnccBlqi0mcXevYExTaHro0M+uo/Qxahi6JyLz9LpotY9eLtEbYrAOeQXcCm6UhjWnTopQHernmjlR/ibE6JmE8F6tReiBn4; search=6|1581261153229%7Crect%3D40.96202658306895%252C-73.55498286718745%252C40.4487909557045%252C-74.40093013281245%26rid%3D6181%26disp%3Dmap%26mdm%3Dauto%26p%3D3%26z%3D0%26lt%3Dfsbo%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%09%01%096181%09%09%09%090%09US_%09',
        'pragma': 'no-cache',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/75.0.3770.142 Chrome/75.0.3770.142 Safari/537.36'
    }

    def fetch(self, url, params):
        print('HTTP GET request to URL: %s' % url, end='')
        res = requests.get(url, params=params, headers=self.headers)
        print(' | Status code: %s' % res.status_code)
        
        return res
   
    def save_response(self, res):
        with open('res.html', 'w') as html_file:
            html_file.write(res)

    def load_response(self):
        html = ''
        
        with open('res.html', 'r') as html_file:
            for line in html_file:
                html += line
        
        return html
   
    def parse(self, html):
        # parse response
        content = BeautifulSoup(html, 'lxml')
        
        # extract property cards
        cards = content.findAll('article', {'class': 'list-card'})
        
        # extract coordinates script {key: value(not a script tag...div...unique identifier for script looking for)}
        script = content.find('script', {'data-zrr-shared-data-key': 'mobileSearchPageStore'}).text
        
        # loop over property cards
        for card in cards:
            # try to extract image
            try:
                image = card.find('div', {'class': 'list-card-top'}).find('img')['src']
            except:
                image = 'N/A'
                
            # extract items
            items = {
                'url': card.find('a', {'class': 'list-card-link'})['href'],
                'details': [
                            price.text for price in
                            card.find('ul', {'class': 'list-card-details'}).find_all('li')
                          ],
                'address': card.find('address', {'class': 'list-card-addr'}).text,
                'image': image
            }
            
            # try to extract price if not extracted yet
            try:
                items['price'] = card.find('div', {'class': 'list-card-price'}).text

            except:
                pass
            
            # try to extract coordinates from script
            try:
                splitter = '"detailUrl":"' + items['url'] + '","latLong":'
                coords = json.loads(script.split(splitter)[-1].split('},')[0] + '}')
                items['coordinates'] = coords
            except:
                coords = script.split(splitter)[-1].split('},')[0] + '}'
                splitter = '<!--{"queryState":{"mapBounds":'
                
                #try:
                 #   map_bounds = json.loads(coords.split(splitter)[-1])
                  #  items['coordinates'] = map_bounds
                #except:
                 #   items['coordinates'] = 'N/A'
            
            # append scraped items to results list
            self.results.append(items)
            print(json.dumps(items, indent=2))
    
    def to_json(self):
        with open('zillow_rent.json', 'w') as f:
            f.write(json.dumps(self.results, indent=2))
        
    def run(self):
        for page in range(1, 5):
            params = {
                'searchQueryState': '{"pagination":{"currentPage":%s},"usersSearchTerm":"Chicago, IL","mapBounds":{"west":-88.09607811914063,"east":-87.36823388085938,"south":41.606969127843165,"north":42.060251786677156},"regionSelection":[{"regionId":17426,"regionType":6}],"isMapVisible":false,"filterState":{"pmf":{"value":false},"fore":{"value":false},"auc":{"value":false},"nc":{"value":false},"fr":{"value":true},"fsbo":{"value":false},"cmsn":{"value":false},"pf":{"value":false},"fsba":{"value":false}},"isListVisible":true}' % str(page)
            }
            res = self.fetch('https://www.zillow.com/homes/Chicago,-IL_rb/?', params)
            self.parse(res.text)

        self.to_json()
        
        #html = self.load_response()
        #self.parse(html)
        

if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run()
# Out:
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {
#   "url": "https://www.zillow.com/homedetails/918-W-32nd-St-1F-Chicago-IL-60608/2078518393_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "750 sqft"
#   ],
#   "address": "918 W 32nd St #1F, Chicago, IL 60608",
#   "image": "https://photos.zillowstatic.com/p_e/ISvkn801f13li31000000000.jpg",
#   "price": "$1,200/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/5710-N-Spaulding-Ave-APT-2-Chicago-IL-60659/65546321_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "1,300 sqft"
#   ],
#   "address": "5710 N Spaulding Ave APT 2, Chicago, IL 60659",
#   "image": "https://photos.zillowstatic.com/p_e/IS7id8fazwchaf0000000000.jpg",
#   "price": "$1,750/mo"
# }
# {
#   "url": "https://www.zillow.com/b/3125-n-bernard-st-chicago-il-9RzLxD/",
#   "details": [
#     "$1,545 1 bd",
#     "$1,795 2 bds"
#   ],
#   "address": "3125 N Bernard St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISvg434kvah6hf0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/1030-n-state-st-chicago-il-Czpc/",
#   "details": [
#     "$1,450+ Studio",
#     "$2,200+ 1 bd",
#     "$2,475+ 2 bds"
#   ],
#   "address": "1030 N State St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISjbckuttnvq9w1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/S-Wells-St-Chicago-IL-60607/2078518425_zpid/",
#   "details": [
#     "1 bd",
#     "2 ba",
#     "1,020 sqft"
#   ],
#   "address": "S Wells St, Chicago, IL 60607",
#   "image": "https://photos.zillowstatic.com/p_e/IS3zjxm5p41dot1000000000.jpg",
#   "price": "$2,275/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Sandburg-Ter-Chicago-IL-60610/2078518431_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "N Sandburg Ter, Chicago, IL 60610",
#   "image": "https://photos.zillowstatic.com/p_e/ISb1bqr676q2tr1000000000.jpg",
#   "price": "$2,400/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Marine-Dr-Chicago-IL-60640/2078518469_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "750 sqft"
#   ],
#   "address": "N Marine Dr, Chicago, IL 60640",
#   "image": "https://photos.zillowstatic.com/p_e/IS3blaruo5ki511000000000.jpg",
#   "price": "$1,035/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Kingsbury-St-Chicago-IL-60610/2078518481_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "N Kingsbury St, Chicago, IL 60610",
#   "image": "N/A",
#   "price": "$2,100/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/235A-W-Van-Buren-St-2312-Chicago-IL-60607/2078518491_zpid/",
#   "details": [
#     "2 bds",
#     "2 ba",
#     "1,200 sqft"
#   ],
#   "address": "235A W Van Buren St #2312, Chicago, IL 60607",
#   "image": "https://photos.zillowstatic.com/p_e/ISjf7z13yb021w0000000000.jpg",
#   "price": "$2,400/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1314-W-Roscoe-St-APT-1-Chicago-IL-60657/2108769027_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "1,350 sqft"
#   ],
#   "address": "1314 W Roscoe St APT 1, Chicago, IL 60657",
#   "image": "...",
#   "price": "$2,175/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1362-n.-bosworth-chicago-il-9dVH/",
#   "details": [
#     "$1,650+ 2 bds"
#   ],
#   "address": "1362 N. Bosworth | 1362 N Bosworth Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/W-19th-St-Chicago-IL-60608/2091433892_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "W 19th St, Chicago, IL 60608",
#   "image": "...",
#   "price": "$1,000/mo"
# }
# {
#   "url": "https://www.zillow.com/b/landing%3a-monthly-leases,-designer-furnished,-%240-deposit-in-chicago-chicago-il-9Rwsts/",
#   "details": [
#     "$1,808+ Studio",
#     "$1,876+ 1 bd",
#     "$4,827 2 bds"
#   ],
#   "address": "Landing: Monthly Leases, Designer Furnished, $0 Deposit in Chicago | 1407 S Michigan Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/landing%3a-monthly-leases-in-chicago,-designer-furnished,-%240-deposit-chicago-il-9Ry34s/",
#   "details": [
#     "$1,808+ Studio",
#     "$1,876+ 1 bd",
#     "$4,827 2 bds"
#   ],
#   "address": "Landing: Monthly Leases in Chicago, Designer Furnished, $0 Deposit | 541 N Fairbanks Ct, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2904-w-belmont-ave-chicago-il-5XjLzs/",
#   "details": [
#     "$2,370 2 bds",
#     "$2,740 3 bds"
#   ],
#   "address": "2904 W Belmont Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/1547-W-Wabansia-Ave-Z2N5WE3KT-Chicago-IL-60642/2078713860_zpid/",
#   "details": [
#     "1 bd",
#     "2 ba",
#     "-- sqft"
#   ],
#   "address": "1547 W Wabansia, 1 Bed plus Den and 2 baths 9/1",
#   "image": "...",
#   "price": "$2,250+/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/S-Laflin-St-Chicago-IL-60607/2078518549_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "S Laflin St, Chicago, IL 60607",
#   "image": "...",
#   "price": "$1,850/mo"
# }
# {
#   "url": "https://www.zillow.com/b/the-alfred-chicago-il-F3kF/",
#   "details": [
#     "$1,890+ Studio",
#     "$1,710+ 1 bd",
#     "$3,000+ 2 bds"
#   ],
#   "address": "The Alfred | 30 E Adams St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/5446-N-Spaulding-Ave-FLOOR-1-Chicago-IL-60625/2078518552_zpid/",
#   "details": [
#     "3 bds",
#     "1.5 ba",
#     "1,400 sqft"
#   ],
#   "address": "5446 N Spaulding Ave FLOOR 1, Chicago, IL 60625",
#   "image": "N/A",
#   "price": "$1,700/mo"
# }
# {
#   "url": "https://www.zillow.com/b/the-bush-temple-chicago-il-9qwkQ9/",
#   "details": [
#     "$1,450+ Studio",
#     "$1,700+ 1 bd",
#     "$3,100+ 2 bds"
#   ],
#   "address": "The Bush Temple | 108 W Chicago Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/445-w-barry-chicago-il-5XgGR6/",
#   "details": [
#     "$1,075+ Studio",
#     "$1,375+ 1 bd"
#   ],
#   "address": "445 W Barry | 445 W Barry Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/1215-W-Melrose-St-REAR-2F-Chicago-IL-60657/2078518562_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,800 sqft"
#   ],
#   "address": "1215 W Melrose St REAR 2F, Chicago, IL 60657",
#   "image": "...",
#   "price": "$2,100/mo"
# }
# {
#   "url": "https://www.zillow.com/b/germain-house-chicago-il-9S4pdF/",
#   "details": [
#     "$1,840 Studio",
#     "$2,030+ 1 bd",
#     "$2,828 2 bds"
#   ],
#   "address": "Germain House | 925 W Chicago Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Fairbanks-Ct-Chicago-IL-60611/2078518572_zpid/",
#   "details": [
#     "3 bds",
#     "3 ba",
#     "-- sqft"
#   ],
#   "address": "N Fairbanks Ct, Chicago, IL 60611",
#   "image": "...",
#   "price": "$4,219/mo"
# }
# {
#   "url": "https://www.zillow.com/b/820-s-michigan-ave-chicago-il-F89z/",
#   "details": [
#     "$1,295+ Studio",
#     "$1,695+ 1 bd",
#     "$1,945+ 2 bds"
#   ],
#   "address": "820 S Michigan Ave | 820 S Michigan Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/713-n-milwaukee-ave-chicago-il-65cSHR/",
#   "details": [
#     "$2,050+ 1 bd",
#     "$2,425+ 2 bds"
#   ],
#   "address": "713 N Milwaukee Ave | 713 N Milwaukee Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/avenir-chicago-il-BZ3D2d/",
#   "details": [
#     "$1,690+ Studio",
#     "$1,985+ 1 bd",
#     "$3,695+ 2 bds",
#     "$3,785+ 3 bds"
#   ],
#   "address": "Avenir | 730 N Milwaukee Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Morgan-St-Chicago-IL-60607/2078518580_zpid/",
#   "details": [
#     "2 bds",
#     "2 ba",
#     "-- sqft"
#   ],
#   "address": "N Morgan St, Chicago, IL 60607",
#   "image": "...",
#   "price": "$4,900/mo"
# }
# {
#   "url": "https://www.zillow.com/b/3260-%26-3270-n-lake-shore-drive-chicago-il-BhNccM/",
#   "details": [
#     "$1,660+ 1 bd",
#     "$4,125 2 bds",
#     "$3,715+ 3 bds"
#   ],
#   "address": "3260 & 3270 N Lake Shore Drive | 3260 & 3270 N Lake Shore Dr N, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2970-n-sheridan-chicago-il-5Xdjyg/",
#   "details": [
#     "$985+ Studio",
#     "$1,390+ 1 bd"
#   ],
#   "address": "2970 N Sheridan | 2970 N Sheridan Rd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-State-St-Chicago-IL-60654/2078518584_zpid/",
#   "details": [
#     "Studio",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "N State St, Chicago, IL 60654",
#   "image": "...",
#   "price": "$1,650/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/445-W-Wellington-Ave-5XDWHPZ8K-Chicago-IL-60657/2078701544_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "445 W Wellington, 1 Bed 1 Bath",
#   "image": "...",
#   "price": "$1,595+/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1164-north-dearborn-street-chicago-il-5Xck78/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,765+ 1 bd"
#   ],
#   "address": "1164 North Dearborn Street | 1164 N Dearborn St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/W-Superior-St-Chicago-IL-60654/2078518587_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "W Superior St, Chicago, IL 60654",
#   "image": "...",
#   "price": "$2,100/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Paulina-St-Chicago-IL-60622/2078518591_zpid/",
#   "details": [
#     "2 bds",
#     "2 ba",
#     "950 sqft"
#   ],
#   "address": "N Paulina St, Chicago, IL 60622",
#   "image": "...",
#   "price": "$2,400/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1501-W-Nelson-St-1F-Chicago-IL-60657/2079044947_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "800 sqft"
#   ],
#   "address": "1501 W Nelson St, Currently No Availability",
#   "image": "...",
#   "price": "$2,400/mo"
# }
# {
#   "url": "https://www.zillow.com/b/3000-n-sheridan-chicago-il-5XgZXW/",
#   "details": [
#     "$3,070 2 bds",
#     "$3,550+ 3 bds",
#     "$3,845 4 bds"
#   ],
#   "address": "3000 N Sheridan | 3000 N Sheridan Rd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/731-s-plymouth-chicago-il-Crzp/",
#   "details": [
#     "$1,599+ 1 bd",
#     "$1,799+ 2 bds",
#     "$2,795+ 3 bds"
#   ],
#   "address": "731 S Plymouth | 731 S Plymouth Ct, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/N-Fairbanks-Ct-Chicago-IL-60611/2078518605_zpid/",
#   "details": [
#     "2 bds",
#     "2 ba",
#     "-- sqft"
#   ],
#   "address": "N Fairbanks Ct, Chicago, IL 60611",
#   "image": "...",
#   "price": "$2,799/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1045-W-Cornelia-Ave-Q7W6YWA6M-Chicago-IL-60657/2079324256_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1045 W Cornelia, 2 bed 1 bath available 8/1",
#   "image": "...",
#   "price": "$2,600+/mo"
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {
#   "url": "https://www.zillow.com/homedetails/W-Wrightwood-Ave-Chicago-IL-60614/2090428941_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "W Wrightwood Ave, Chicago, IL 60614",
#   "image": "https://photos.zillowstatic.com/p_e/ISb5md4qmn0sp90000000000.jpg",
#   "price": "$1,695/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/3049-S-Parnell-Ave-2-Chicago-IL-60616/2078518620_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "900 sqft"
#   ],
#   "address": "3049 S Parnell Ave #2, Chicago, IL 60616",
#   "image": "https://photos.zillowstatic.com/p_e/IS3f8vxoymjea20000000000.jpg",
#   "price": "$1,025/mo"
# }
# {
#   "url": "https://www.zillow.com/b/sono-east-chicago-il-BW3V/",
#   "details": [
#     "$1,778 Studio",
#     "$1,711+ 1 bd",
#     "$3,274+ 2 bds"
#   ],
#   "address": "SoNo East | 840 W Blackhawk St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISzn8qr5mpcojj1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/450-west-melrose-chicago-il-5XgZHM/",
#   "details": [
#     "$1,011+ Studio",
#     "$1,319+ 1 bd"
#   ],
#   "address": "450 West Melrose | 450 W Melrose St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISvwwzgr1cnhus1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/5120-s.-hyde-park-boulevard-chicago-il-5XcW7W/",
#   "details": [
#     "$1,055+ Studio"
#   ],
#   "address": "5120 S. Hyde Park Boulevard | 5120 S Hyde Park Blvd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7e6gl1u3xyui0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1940-N-Lincoln-Ave-1067194-Chicago-IL-60614/2105535641_zpid/",
#   "details": [
#     "Studio",
#     "1 ba",
#     "275 sqft"
#   ],
#   "address": "1940 N Lincoln Ave, Studio",
#   "image": "https://photos.zillowstatic.com/p_e/IS6210gi68yg8s1000000000.jpg",
#   "price": "$1,124+/mo"
# }
# {
#   "url": "https://www.zillow.com/b/244-e.-pearson-chicago-il-9Rxr3w/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,695+ 1 bd"
#   ],
#   "address": "244 E. Pearson | 244 E Pearson St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISr943lk8lbyta1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/1336-n-damen-chicago-il-5hGVdZ/",
#   "details": [
#     "$2,400 2 bds",
#     "$3,750 3 bds"
#   ],
#   "address": "1336 N Damen | 1336 N Damen Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7msygen5uour1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/612-west-patterson-avenue-chicago-il-5XhJG5/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,395+ 1 bd"
#   ],
#   "address": "612 West Patterson Avenue | 612 W Patterson Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS3z7wxntjjy4g1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/the-aberdeen-west-loop-chicago-il-5ZgrJT/",
#   "details": [
#     "$2,495 1 bd",
#     "$2,895+ 2 bds"
#   ],
#   "address": "The Aberdeen West Loop | 20 N Aberdeen St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/lincoln-1955-n-chicago-il-9RyW7B/",
#   "details": [
#     "$1,795+ 1 bd"
#   ],
#   "address": "Lincoln 1955 N | 1955 N Lincoln Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/1330-n-dearborn-chicago-il-5XhGwj/",
#   "details": [
#     "$1,360+ Studio",
#     "$1,410+ 1 bd"
#   ],
#   "address": "1330 N Dearborn | 1330 N Dearborn St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/warren-chicago-il-63dtBL/",
#   "details": [
#     "$2,250+ 2 bds"
#   ],
#   "address": "Warren | 1609 W Warren Blvd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/southport-lofts-chicago-il-DCFv/",
#   "details": [
#     "$1,536+ Studio",
#     "$1,924+ 1 bd",
#     "$2,972+ 2 bds"
#   ],
#   "address": "Southport Lofts | 2061 N Southport Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/millennium-park-plaza-chicago-il-9bmb/",
#   "details": [
#     "$1,515+ Studio",
#     "$1,645+ 1 bd",
#     "$2,365+ 2 bds",
#     "$3,115+ 3 bds"
#   ],
#   "address": "Millennium Park Plaza | 151 N Michigan Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/420-e-ohio-chicago-il-5XdDLs/",
#   "details": [
#     "$1,499+ Studio",
#     "$2,276+ 1 bd",
#     "$2,885+ 2 bds",
#     "$3,867+ 3 bds"
#   ],
#   "address": "420 E Ohio | 420 E Ohio St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/the-jax-chicago-il-BK9z84/",
#   "details": [
#     "$1,473+ Studio",
#     "$1,805+ 1 bd",
#     "$3,415+ 2 bds"
#   ],
#   "address": "The Jax | 1220 W Jackson Blvd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/upshore-chapter-chicago-il-BPtGcx/",
#   "details": [
#     "$1,288+ Studio",
#     "$1,377+ 1 bd",
#     "$2,376 2 bds"
#   ],
#   "address": "Upshore Chapter | 4555 N Sheridan Rd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/mica-chicago-il-9nbRQR/",
#   "details": [
#     "$1,995+ 1 bd",
#     "$2,695 2 bds",
#     "$3,395+ 3 bds"
#   ],
#   "address": "MiCA | 2210 N Washtenaw Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/arkadia-west-loop-chicago-il-BLV4/",
#   "details": [
#     "$1,597+ Studio",
#     "$1,908+ 1 bd",
#     "$2,693+ 2 bds"
#   ],
#   "address": "Arkadia West Loop | 765 W Adams St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/lake-shore-plaza-chicago-il-5XfXYV/",
#   "details": [
#     "$1,492+ Studio",
#     "$1,400+ 1 bd",
#     "$2,400+ 2 bds"
#   ],
#   "address": "Lake Shore Plaza | 445 E Ohio St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/3018-W-Wabansia-Ave-Chicago-IL-60647/2078518982_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "450 sqft"
#   ],
#   "address": "3018 W Wabansia Ave, Chicago, IL 60647",
#   "image": "...",
#   "price": "$1,100/mo"
# }
# {
#   "url": "https://www.zillow.com/b/wrightwood-512-w-wrightwood-ave-chicago-il-BfdG/",
#   "details": [
#     "$1,435 Studio",
#     "$1,725+ 1 bd",
#     "$2,587 2 bds"
#   ],
#   "address": "Wrightwood - 512 W Wrightwood Ave | 512 W Wrightwood Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/15-25-n-bishop-chicago-il-5XfX68/",
#   "details": [
#     "$3,675+ 3 bds"
#   ],
#   "address": "15-25 N Bishop | 15 N Bishop St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/seven-10-west-chicago-il-9S69wd/",
#   "details": [
#     "$1,695+ 1 bd",
#     "$2,595+ 2 bds"
#   ],
#   "address": "Seven 10 West | 710 W Grand Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/625-w-wrightwood-chicago-il-C65B/",
#   "details": [
#     "$1,325+ Studio",
#     "$1,625+ 1 bd"
#   ],
#   "address": "625 W Wrightwood | 625 W Wrightwood Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/1225-old-town-chicago-il-CQpR/",
#   "details": [
#     "$1,870+ Studio",
#     "$2,383+ 1 bd",
#     "$3,303+ 2 bds",
#     "$4,630+ 3 bds"
#   ],
#   "address": "1225 Old Town | 1225 N Wells St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/3257-3267-w.-wrightwood-ave-chicago-il-BM9Hk6/",
#   "details": [
#     "$965+ Studio",
#     "$1,395+ 1 bd"
#   ],
#   "address": "3257 - 3267 W. Wrightwood Ave | 3257-3267 W Wrightwood Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/4070-n.-kenmore-chicago-il-9RyL9j/",
#   "details": [
#     "$975+ Studio"
#   ],
#   "address": "4070 N. Kenmore | 4070 N Kenmore Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2150-w-lawrence-avenue-chicago-il-CqgP/",
#   "details": [
#     "$1,895+ 1 bd",
#     "$2,495+ 2 bds"
#   ],
#   "address": "2150 W Lawrence Avenue | 2150 W Lawrence Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/4600-4608-n.-beacon-chicago-il-9hJDLg/",
#   "details": [
#     "$850+ Studio"
#   ],
#   "address": "4600 - 4608 N. Beacon | 4600-4608 N Beacon St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2756-n-pine-grove-chicago-il-5Xg3d2/",
#   "details": [
#     "$1,447+ 1 bd",
#     "$1,949+ 2 bds"
#   ],
#   "address": "2756 N Pine Grove | 2756 N Pine Grove Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/225-w-huron-st-chicago-il-5XgGJp/",
#   "details": [
#     "$1,600+ 1 bd"
#   ],
#   "address": "225 W Huron St | 225 W Huron St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/600-n-lake-shore-dr-chicago-il-5Xj6m5/",
#   "details": [
#     "$1,890 Studio",
#     "$2,400+ 1 bd",
#     "$3,400+ 2 bds",
#     "$6,950+ 3 bds"
#   ],
#   "address": "600 N Lake Shore Dr, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/3308-W-Ainslie-St-3-Chicago-IL-60625/2078519287_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "1,100 sqft"
#   ],
#   "address": "3308 W Ainslie St #3, Chicago, IL 60625",
#   "image": "...",
#   "price": "$1,250/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1742-w-division-st-chicago-il-Cx8J/",
#   "details": [
#     "$2,600+ 2 bds"
#   ],
#   "address": "1742 W Division St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/1316-W-Diversey-Pkwy-1-Chicago-IL-60614/2078520023_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "1,000 sqft"
#   ],
#   "address": "1316 W Diversey Pkwy #1, Chicago, IL 60614",
#   "image": "...",
#   "price": "$1,995/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/7359-N-Hoyne-Ave-APT-3-Chicago-IL-60645/2124457366_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,600 sqft"
#   ],
#   "address": "7359 N Hoyne Ave APT 3, Chicago, IL 60645",
#   "image": "...",
#   "price": "$1,550/mo"
# }
# {
#   "url": "https://www.zillow.com/b/20-e-goethe-st-chicago-il-BVZW/",
#   "details": [
#     "$1,495+ 1 bd"
#   ],
#   "address": "20 E Goethe St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/732-W-Roscoe-St-APT-1S-Chicago-IL-60657/2126744438_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "1,000 sqft"
#   ],
#   "address": "732 W Roscoe St APT 1S, Chicago, IL 60657",
#   "image": "...",
#   "price": "$1,695/mo"
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {
#   "url": "https://www.zillow.com/b/4721-s.-ellis-avenue-chicago-il-Bh9wgM/",
#   "details": [
#     "$905+ Studio",
#     "$1,085+ 1 bd",
#     "$1,225+ 2 bds"
#   ],
#   "address": "4721 S. Ellis Avenue | 4721-29 S Ellis Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISjz6cnylf6wr00000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/61-e-21st-st-chicago-il-B36RT3/",
#   "details": [
#     "$1,150+ Studio",
#     "$1,325+ 1 bd",
#     "$1,999+ 2 bds"
#   ],
#   "address": "61 E 21st St | 61 E 21st St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISfk06pn4q3fn81000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/2317-27-north-rockwell-street-chicago-il-9S5Pm6/",
#   "details": [
#     "$1,325+ Studio",
#     "$1,595+ 1 bd",
#     "$1,950+ 2 bds"
#   ],
#   "address": "2317-27 North Rockwell Street | 2317 N Rockwell St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7ilykmruu5mc1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/1331-w.-estes-chicago-il-9YTZ/",
#   "details": [
#     "$945+ Studio",
#     "$1,095+ 1 bd"
#   ],
#   "address": "1331 W. Estes | 1331 W Estes Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISzfu5kctxkpaa0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/elevation-lofts-chicago-il-BMwvfR/",
#   "details": [
#     "$1,625+ 2 bds",
#     "$3,000+ 3 bds"
#   ],
#   "address": "Elevation Lofts | 1531 W Howard St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISjje7sfw278yj0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/residences-at-8-east-huron-chicago-il-9Ry5bB/",
#   "details": [
#     "$2,097+ 1 bd",
#     "$3,948+ 2 bds"
#   ],
#   "address": "Residences at 8 East Huron | 8 E Huron St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS3jbccrmwtv1b1000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/440-n-mcclurg-ct-chicago-il-5XdPRj/",
#   "details": [
#     "$1,500+ Studio",
#     "$1,795+ 1 bd",
#     "$3,500 2 bds"
#   ],
#   "address": "440 N Mcclurg Ct, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISvw42o4xdym951000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/1435-N-Dearborn-St-Chicago-IL/41.908802,-87.629749_ll/",
#   "details": [
#     "$1,550+ 1 bd"
#   ],
#   "address": "1435 N Dearborn St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISrlhp0uaqhbb21000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/5748-s-blackstone-ave-chicago-il-9S3y7V/",
#   "details": [
#     "$659+ Studio"
#   ],
#   "address": "5748 S Blackstone Ave | 5748 S Blackstone Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISb9puexj4l45o0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/707-W-Brompton-Ave-Chicago-IL-60657/2098318262_zpid/",
#   "details": [
#     "Studio",
#     "1 ba",
#     "540 sqft"
#   ],
#   "address": "707 W Brompton Ave, Chicago, IL 60657",
#   "image": "...",
#   "price": "$1,300/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1200-w-waveland-ave-chicago-il-C8MF/",
#   "details": [
#     "$1,795+ 2 bds"
#   ],
#   "address": "1210 W Waveland Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/632-west-addison-chicago-il-5XcZFX/",
#   "details": [
#     "$1,052+ Studio",
#     "$1,293+ 1 bd",
#     "$2,000+ 2 bds"
#   ],
#   "address": "632 West Addison | 632 W Addison St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/534-W-Arlington-Pl-Chicago-IL-60614/2094459170_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "534 W Arlington Pl, Chicago, IL 60614",
#   "image": "...",
#   "price": "$2,350/mo"
# }
# {
#   "url": "https://www.zillow.com/b/100-west-chestnut-chicago-il-5Xj9Gt/",
#   "details": [
#     "$1,415+ 1 bd",
#     "$2,082+ 2 bds"
#   ],
#   "address": "100 West Chestnut | 100 W Chestnut St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/emme-chicago-chicago-il-BFG6rV/",
#   "details": [
#     "$1,750+ Studio",
#     "$2,050+ 1 bd",
#     "$3,134+ 2 bds"
#   ],
#   "address": "Emme Chicago | 165 N Desplaines St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/2636-N-Mildred-Ave-Chicago-IL-60614/2104447421_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "1,600 sqft"
#   ],
#   "address": "2636 N Mildred Ave, Chicago, IL 60614",
#   "image": "...",
#   "price": "$3,300/mo"
# }
# {
#   "url": "https://www.zillow.com/b/cornelia-%26-stratford-chicago-il-Cr4s/",
#   "details": [
#     "$990+ Studio",
#     "$1,480+ 1 bd",
#     "$3,995 3 bds",
#     "$3,975+ 4 bds"
#   ],
#   "address": "Cornelia & Stratford | 535 W Cornelia Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/18-e.-elm-chicago-il-5XcSsd/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,375+ 1 bd",
#     "$2,285+ 2 bds"
#   ],
#   "address": "18 E. Elm | 18 E Elm St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/xavier-chicago-il-5q4SqT/",
#   "details": [
#     "$1,700+ Studio",
#     "$2,089+ 1 bd",
#     "$2,850+ 2 bds"
#   ],
#   "address": "Xavier | 625 W Division St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/4226-N-Clark-St-3-Chicago-IL-60613/2108358558_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "650 sqft"
#   ],
#   "address": "4226 N Clark St #3, Chicago, IL 60613",
#   "image": "...",
#   "price": "$1,315/mo"
# }
# {
#   "url": "https://www.zillow.com/b/fullerton-chicago-il-64kb96/",
#   "details": [
#     "$2,200+ 2 bds",
#     "$2,800+ 3 bds"
#   ],
#   "address": "Fullerton | 1540 W Fullerton Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2900-north-mildred-avenue-chicago-il-CQqB/",
#   "details": [
#     "$1,395+ Studio",
#     "$1,595+ 1 bd"
#   ],
#   "address": "2900 North Mildred Avenue | 2900 N Mildred Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/cobbler-square-lofts-chicago-il-5XfPr9/",
#   "details": [
#     "$1,415+ Studio",
#     "$1,880+ 1 bd",
#     "$2,680+ 2 bds"
#   ],
#   "address": "Cobbler Square Lofts | 1350 N Wells St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/the-sutherland-chicago-il-5XmM62/",
#   "details": [
#     "$1,150+ Studio",
#     "$1,472+ 1 bd",
#     "$1,683+ 2 bds"
#   ],
#   "address": "The Sutherland | 4659 S Drexel Blvd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/726-W-Roscoe-St-APT-3N-Chicago-IL-60657/2105890245_zpid/",
#   "details": [
#     "Studio",
#     "1 ba",
#     "500 sqft"
#   ],
#   "address": "726 W Roscoe St APT 3N, Chicago, IL 60657",
#   "image": "...",
#   "price": "$1,245/mo"
# }
# {
#   "url": "https://www.zillow.com/b/5300-5308-s.-hyde-park-boulevard-chicago-il-9ggKFq/",
#   "details": [
#     "$979+ Studio",
#     "$1,240+ 1 bd",
#     "$1,425+ 2 bds"
#   ],
#   "address": "5300-5308 S. Hyde Park Boulevard | 5300-5308 S Hyde Park Blvd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/2020-n-lincoln-park-w-chicago-il-5Xj6LK/",
#   "details": [
#     "$1,600+ Studio",
#     "$1,850+ 1 bd",
#     "$3,000 2 bds"
#   ],
#   "address": "2020 N Lincoln Park W, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/2247-W-Lawrence-Ave-6W9JHFWQB-Chicago-IL-60625/2080983536_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "-- sqft"
#   ],
#   "address": "2247 W Lawrence Ave, 401 - flexible move in date",
#   "image": "...",
#   "price": "$2,700+/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/6950-N-Ashland-Blvd-UNIT-E-Chicago-IL-60626/2078519726_zpid/",
#   "details": [
#     "3 bds",
#     "2.5 ba",
#     "1,148 sqft"
#   ],
#   "address": "6950 N Ashland Blvd UNIT E, Chicago, IL 60626",
#   "image": "...",
#   "price": "$2,500/mo"
# }
# {
#   "url": "https://www.zillow.com/b/the-van-buren-chicago-il-BCgw9W/",
#   "details": [
#     "$1,892+ 1 bd",
#     "$2,800+ 2 bds"
#   ],
#   "address": "The Van Buren | 808 W Van Buren St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/city-hyde-park-chicago-il-65cp2d/",
#   "details": [
#     "$2,175+ 1 bd",
#     "$2,575+ 2 bds",
#     "$3,150+ 3 bds"
#   ],
#   "address": "City Hyde Park | 5105 S Harper Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/drexel-terrace-chicago-il-5Xfb8G/",
#   "details": [
#     "$1,085+ 1 bd"
#   ],
#   "address": "Drexel Terrace | 5043 S Drexel Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/reside-on-green-street-chicago-il-65hP6n/",
#   "details": [
#     "$1,718+ Studio",
#     "$2,035+ 1 bd",
#     "$3,229+ 2 bds",
#     "$5,150+ 3 bds"
#   ],
#   "address": "Reside on Green Street | 504 N Green St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/amli-lofts-chicago-il-5gqkLB/",
#   "details": [
#     "$1,689+ Studio",
#     "$1,943+ 1 bd",
#     "$2,891+ 2 bds"
#   ],
#   "address": "AMLI Lofts | 850 S Clark St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/the-shoreham-at-lakeshore-east-chicago-il-5Xh5X6/",
#   "details": [
#     "$1,444+ Studio",
#     "$1,616+ 1 bd",
#     "$2,516+ 2 bds"
#   ],
#   "address": "The Shoreham at Lakeshore East | 400 E South Water St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/k2-apartments-chicago-il-5XkG63/",
#   "details": [
#     "$1,657+ Studio",
#     "$2,099+ 1 bd",
#     "$3,391 2 bds",
#     "$4,739 3 bds"
#   ],
#   "address": "K2 Apartments | 365 N Halsted St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/roosevelt-collection-lofts-chicago-il-5ZbvP7/",
#   "details": [
#     "$1,685+ 1 bd",
#     "$2,107+ 2 bds"
#   ],
#   "address": "Roosevelt Collection Lofts | 1135 S Delano Ct, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/1111-n-dearborn-chicago-il-5XggMm/",
#   "details": [
#     "$1,294+ Studio",
#     "$1,415+ 1 bd",
#     "$2,165+ 2 bds",
#     "$3,000+ 3 bds"
#   ],
#   "address": "1111 N Dearborn | 1111 N Dearborn St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/shoreland-chicago-il-CKF7/",
#   "details": [
#     "$1,750+ Studio",
#     "$1,660+ 1 bd",
#     "$2,200+ 2 bds",
#     "$3,400+ 3 bds"
#   ],
#   "address": "Shoreland | 5454 S Shore Dr, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/the-madison-at-racine-chicago-il-CR2b/",
#   "details": [
#     "$1,952+ Studio",
#     "$2,011+ 1 bd",
#     "$3,274+ 2 bds"
#   ],
#   "address": "The Madison at Racine | 1164 W Madison St, Chicago, IL",
#   "image": "..."
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {
#   "url": "https://www.zillow.com/b/reside-on-irving-park-chicago-il-5XjJ4Y/",
#   "details": [
#     "$1,525+ 1 bd",
#     "$2,715 3 bds"
#   ],
#   "address": "Reside on Irving Park | 725 W Irving Park Rd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISzjxategq82x80000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/kingsbury-plaza-chicago-il-5XfX8x/",
#   "details": [
#     "$1,682+ Studio",
#     "$2,630+ 1 bd",
#     "$3,434+ 2 bds"
#   ],
#   "address": "Kingsbury Plaza | 520 N Kingsbury St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7umn696p7i711000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/b/next-apartments-chicago-il-65gycw/",
#   "details": [
#     "$1,583+ Studio",
#     "$2,276+ 1 bd",
#     "$3,022+ 2 bds",
#     "$5,910+ 3 bds"
#   ],
#   "address": "NEXT Apartments | 347 W Chestnut St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISesiputa13yds0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/2318-W-Palmer-St-2-Chicago-IL-60647/2078520094_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "850 sqft"
#   ],
#   "address": "2318 W Palmer St #2, Chicago, IL 60647",
#   "image": "https://photos.zillowstatic.com/p_e/IS7uiweed1j0rp1000000000.jpg",
#   "price": "$1,650/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1133-n-dearborn-chicago-il-5XgZxC/",
#   "details": [
#     "$1,465+ Studio",
#     "$1,740+ 1 bd",
#     "$2,552+ 2 bds"
#   ],
#   "address": "1133 N Dearborn | 1133 N Dearborn St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISjndxub5kmrd90000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/3851-N-Kedvale-Ave-C3-Chicago-IL-60641/2078520117_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "3851 N Kedvale Ave #C3, Chicago, IL 60641",
#   "image": "https://photos.zillowstatic.com/p_e/ISnulj4lhw0rug1000000000.jpg",
#   "price": "$1,400/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/545-W-Division-St-QDNVRE6GS-Chicago-IL-60610/2087637760_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "861 sqft"
#   ],
#   "address": "Larrabee Place at Parkside of Old Town, One Bedroom",
#   "image": "https://photos.zillowstatic.com/p_e/ISibkqgxaf3joh1000000000.jpg",
#   "price": "$1,520+/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/3636-W-Shakespeare-Ave-G-Chicago-IL-60647/2101321171_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,500 sqft"
#   ],
#   "address": "3636 W Shakespeare Ave #G, Chicago, IL 60647",
#   "image": "https://photos.zillowstatic.com/p_e/IS3v4nt6zphfn81000000000.jpg",
#   "price": "$1,695/mo"
# }
# {
#   "url": "https://www.zillow.com/b/535-n-michigan-avenue-chicago-il-5XfC4d/",
#   "details": [
#     "$1,295+ Studio",
#     "$1,675+ 1 bd",
#     "$2,450+ 2 bds"
#   ],
#   "address": "535 N Michigan Avenue | 535 N Michigan Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISr90ctpbqar6r0000000000.jpg"
# }
# {
#   "url": "https://www.zillow.com/homedetails/901-W-Armitage-Ave-3-Chicago-IL-60614/2088687415_zpid/",
#   "details": [
#     "4 bds",
#     "2 ba",
#     "1,500 sqft"
#   ],
#   "address": "901 W Armitage Ave #3, Chicago, IL 60614",
#   "image": "...",
#   "price": "$3,480/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/2224-W-Irving-Park-Rd-3-Chicago-IL-60618/2078520181_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,100 sqft"
#   ],
#   "address": "2224 W Irving Park Rd #3, Chicago, IL 60618",
#   "image": "...",
#   "price": "$1,750/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/4153-N-Kimball-Ave-APT-3-Chicago-IL-60618/2105371073_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "800 sqft"
#   ],
#   "address": "4153 N Kimball Ave APT 3, Chicago, IL 60618",
#   "image": "...",
#   "price": "$1,100/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1429-W-Gregory-St-1-Chicago-IL-60640/3698604_zpid/",
#   "details": [
#     "4 bds",
#     "2 ba",
#     "4,500 sqft"
#   ],
#   "address": "1429 W Gregory St #1, Chicago, IL 60640",
#   "image": "...",
#   "price": "$3,800/mo"
# }
# {
#   "url": "https://www.zillow.com/b/88-w-schiller-st-chicago-il-9SHy/",
#   "details": [
#     "$1,450 Studio",
#     "$1,500+ 1 bd"
#   ],
#   "address": "88 W Schiller St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/1429-W-Gregory-St-2-Chicago-IL-60640/2078520180_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1429 W Gregory St #2, Chicago, IL 60640",
#   "image": "...",
#   "price": "$2,800/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/2400-N-Surrey-Ct-1-Chicago-IL-60614/2107183700_zpid/",
#   "details": [
#     "4 bds",
#     "2 ba",
#     "-- sqft"
#   ],
#   "address": "2400 N Surrey Ct #1, Chicago, IL 60614",
#   "image": "...",
#   "price": "$3,000/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1713-w-north-ave-chicago-il-5ZPhz5/",
#   "details": [
#     "$1,600+ 2 bds"
#   ],
#   "address": "1713 W North Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/1339-N-Dearborn-Pkwy-Chicago-IL/41.907123,-87.630082_ll/",
#   "details": [
#     "$1,350+ Studio",
#     "$1,450+ 1 bd",
#     "$1,975+ 2 bds",
#     "$5,750 3 bds"
#   ],
#   "address": "1339 N Dearborn Pkwy, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/b/5415-n-sheridan-rd-chicago-il-DB7z/",
#   "details": [
#     "$1,050+ Studio",
#     "$1,295+ 1 bd"
#   ],
#   "address": "5415 N Sheridan Rd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/5224-N-Winthrop-Ave-APT-2C-Chicago-IL-60640/2078520182_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "800 sqft"
#   ],
#   "address": "5224 N Winthrop Ave APT 2C, Chicago, IL 60640",
#   "image": "...",
#   "price": "$1,550/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1114-W-Taylor-St-4-Chicago-IL-60607/2078520204_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "800 sqft"
#   ],
#   "address": "1114 W Taylor St #4, Chicago, IL 60607",
#   "image": "N/A",
#   "price": "$1,400/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1114-W-Taylor-St-APT-5-Chicago-IL-60607/2078520203_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "700 sqft"
#   ],
#   "address": "1114 W Taylor St APT 5, Chicago, IL 60607",
#   "image": "N/A",
#   "price": "$1,375/mo"
# }
# {
#   "url": "https://www.zillow.com/b/reside-on-jackson-chicago-il-9kFtKX/",
#   "details": [
#     "$2,145+ 1 bd",
#     "$2,745+ 2 bds",
#     "$3,600 3 bds"
#   ],
#   "address": "Reside on Jackson | 1241-1245 W Jackson Blvd, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/2536-N-Sawyer-Ave-625GCCZ9K-Chicago-IL-60647/2080264387_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "2536 N Sawyer Avenue, 1 Bedroom",
#   "image": "...",
#   "price": "$1,350+/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1336-W-83rd-St-2-Chicago-IL-60620/2101681047_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1336 W 83rd St #2, Chicago, IL 60620",
#   "image": "...",
#   "price": "$950/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1649-W-83rd-St-UNIT-3N-Chicago-IL-60620/2078520271_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1649 W 83rd St UNIT 3N, Chicago, IL 60620",
#   "image": "...",
#   "price": "$1,145/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1444-W-83rd-St-1-Chicago-IL-60620/2078520266_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1444 W 83rd St #1, Chicago, IL 60620",
#   "image": "...",
#   "price": "$810/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1114-S-Francisco-Ave-2-Chicago-IL-60612/2078520267_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1114 S Francisco Ave #2, Chicago, IL 60612",
#   "image": "...",
#   "price": "$1,300/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1837-E-72nd-St-3-Chicago-IL-60649/2078520283_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1837 E 72nd St #3, Chicago, IL 60649",
#   "image": "...",
#   "price": "$1,145/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/1316-W-82nd-St-2-Chicago-IL-60620/2103423200_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "1316 W 82nd St #2, Chicago, IL 60620",
#   "image": "...",
#   "price": "$950/mo"
# }
# {
#   "url": "https://www.zillow.com/b/2356-w-harrison-st-chicago-il-5XjScJ/",
#   "details": [
#     "$1,900+ 2 bds"
#   ],
#   "address": "2356 W Harrison St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/4114-W-Gladys-Ave-B-Chicago-IL-60624/2079527400_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "4114 W Gladys Ave #B, Chicago, IL 60624",
#   "image": "...",
#   "price": "$950/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/741-S-Claremont-Ave-3C-Chicago-IL-60612/2078520286_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "1,500 sqft"
#   ],
#   "address": "741 S Claremont Ave #3C, Chicago, IL 60612",
#   "image": "...",
#   "price": "$1,950/mo"
# }
# {
#   "url": "https://www.zillow.com/b/2350-w-harrison-st-chicago-il-CYcS/",
#   "details": [
#     "$1,950+ 2 bds"
#   ],
#   "address": "2352 W Harrison St, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/8021-S-Maryland-Ave-1F-Chicago-IL-60619/2078520296_zpid/",
#   "details": [
#     "2 bds",
#     "1 ba",
#     "-- sqft"
#   ],
#   "address": "8021 S Maryland Ave #1F, Chicago, IL 60619",
#   "image": "...",
#   "price": "$700/mo"
# }
# {
#   "url": "https://www.zillow.com/b/1534-south-komensky-avenue-1f-chicago-il-5XcxvY/",
#   "details": [
#     "$1,150+ 2 bds"
#   ],
#   "address": "1534 South Komensky Avenue - 1F | 1534 S Komensky Ave, Chicago, IL",
#   "image": "..."
# }
# {
#   "url": "https://www.zillow.com/homedetails/7148-S-Campbell-Ave-2-Chicago-IL-60629/2083382587_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,200 sqft"
#   ],
#   "address": "7148 S Campbell Ave #2, Chicago, IL 60629",
#   "image": "...",
#   "price": "$1,250/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/7437-S-Chappel-Ave-1N-Chicago-IL-60649/2078520305_zpid/",
#   "details": [
#     "3 bds",
#     "2 ba",
#     "1,250 sqft"
#   ],
#   "address": "7437 S Chappel Ave #1N, Chicago, IL 60649",
#   "image": "...",
#   "price": "$1,375/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/12018-S-Wallace-St-FLOOR-2-Chicago-IL-60628/2078520304_zpid/",
#   "details": [
#     "3 bds",
#     "1 ba",
#     "1,200 sqft"
#   ],
#   "address": "12018 S Wallace St FLOOR 2, Chicago, IL 60628",
#   "image": "...",
#   "price": "$1,300/mo"
# }
# {
#   "url": "https://www.zillow.com/homedetails/634-W-Cornelia-Ave-1044552-Chicago-IL-60657/2093249626_zpid/",
#   "details": [
#     "1 bd",
#     "1 ba",
#     "580 sqft"
#   ],
#   "address": "634 W Cornelia, 1 Bedroom",
#   "image": "...",
#   "price": "$1,383+/mo"
# }

# %% [markdown]
# from googlegeocoder import GoogleGeocoder
# geocoder = GoogleGeocoder()
# list_of_addresses = [
#     '1727 E 107th St, Los Angeles, CA',
#     '317 Broadway, Los Angeles, CA'
# ]
#
# key=AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8
#
# for address in list_of_addresses:
#     try:
#         search = geocoder.get(address)
#     except ValueError:
#         continue
#     first_result = search[0]
#     output =  [
#         first_result.formatted_address,
#         first_result.geometry.location.lat,
#         first_result.geometry.location.lng,
#         first_result.geometry.location_type
#     ]
#     print(str, output)

# %% [markdown]
# import requests
#
# URL = "https://geocode.search.hereapi.com/v1/geocode"
# location = input("Enter the location here: ") #taking user input
# api_key = 'AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8' # Acquire from developer.here.com
# PARAMS = {'apikey':api_key,'q':location}
#
# # sending get request and saving the response as response object
# r = requests.get(url = URL, params = PARAMS)
# data = r.json()
#
# latitude = data['items'][0]['position']['lat']
# longitude = data['items'][0]['position']['lng']

# %% [markdown]
# # API KEY: AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8

# %% [markdown]
# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="geoapiExercises")
# ladd1 = "27488 Stanford Avenue, North Dakota"
# print("Location address:",ladd1)
# location = geolocator.geocode(ladd1)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
# ladd2 = "380 New York St, Redlands, CA 92373"
# print("\nLocation address:",ladd2)
# location = geolocator.geocode(ladd2)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
# ladd3 = "1600 Pennsylvania Avenue NW"
# print("\nLocation address:",ladd3)
# location = geolocator.geocode(ladd3)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
