# %% [markdown]
# import requests
# from bs4 import BeautifulSoup
# import csv
# import json
#
#
# class ZillowScraper:
#     results = []
#
#     headers = {
#         'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
#         'accept-encoding': 'gzip, deflate, br',
#         'accept-language': 'en-US,en;q=0.9',
#         'cache-control': 'no-cache',
#         'cookie': 'zguid=23|%2403435e76-0699-4a32-b86d-77d033c907ef; _ga=GA1.2.1271511001.1575011821; zjs_user_id=null; zjs_anonymous_id=%2203435e76-0699-4a32-b86d-77d033c907ef%22; _gcl_au=1.1.1333357279.1575011822; _pxvid=3cfcc163-1278-11ea-bff8-0242ac12000b; ki_r=; __gads=ID=84d8013cfac6df96:T=1575012041:S=ALNI_MaSvVNZsir2JXJ17pv54bjsPuyfcw; ki_s=199442%3A0.0.0.0.0%3B199444%3A0.0.0.0.2; zgsession=1|c0999376-b167-4a47-a1cd-0e456d882d4e; _gid=GA1.2.55965867.1578668946; JSESSIONID=87D0662A6BC141A73F0D12620788519C; KruxPixel=true; DoubleClickSession=true; KruxAddition=true; ki_t=1575011869563%3B1578669044158%3B1578669044158%3B2%3B10; _pxff_tm=1; _px3=2e6809e35ce7e076934ff998c2bdb8140e8b793b53e08a27c5da11f1b4760755:DFItCmrETuS2OQcztcFmt0FYPUn00ihAAue2ynQgbfSq6H+p2yP3Rl3aeyls3Unr1VRJSgcNue8Rr1SUq4P1jA==:1000:9ueZvAJ6v5y4ny7psGF25dK+d3GlytY2Bh+Xj9UUhC4DaioIZ+FMXPU0mOX+Qnghqut0jIT61gLecN4fyu6qXaPDlBX6YsZVbIry1YyBN/37l0Ri3JP+E0h+m+QEBB+bqb6MbE2HtgGBJRJAry8dgOKGM5JtBGdX+X/nuQX1xaw=; AWSALB=E6JYC43gXQRlE2jPT9e2vAQOYPvdHnccBlqi0mcXevYExTaHro0M+uo/Qxahi6JyLz9LpotY9eLtEbYrAOeQXcCm6UhjWnTopQHernmjlR/ibE6JmE8F6tReiBn4; search=6|1581261153229%7Crect%3D40.96202658306895%252C-73.55498286718745%252C40.4487909557045%252C-74.40093013281245%26rid%3D6181%26disp%3Dmap%26mdm%3Dauto%26p%3D3%26z%3D0%26lt%3Dfsbo%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%09%01%096181%09%09%09%090%09US_%09',
#         'pragma': 'no-cache',
#         'upgrade-insecure-requests': '1',
#         'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/75.0.3770.142 Chrome/75.0.3770.142 Safari/537.36'
#     }
#
#     def fetch(self, url, params):
#         print('HTTP GET request to URL: %s' % url, end='')
#         res = requests.get(url, params=params, headers=self.headers)
#         print(' | Status code: %s' % res.status_code)
#
#         return res
#
#     def save_response(self, res):
#         with open('res.html', 'w') as html_file:
#             html_file.write(res)
#
#     def load_response(self):
#         html = ''
#
#         with open('res.html', 'r') as html_file:
#             for line in html_file:
#                 html += line
#
#         return html
#
#     def parse(self, html):
#         content = BeautifulSoup(html, 'lxml')
#         cards = content.findAll('article', {'class': 'list-card'})
#
#         for card in cards:
#             # try to extract image
#             try:
#                 image = card.find('div', {'class': 'list-card-top'}).find('img')['src']
#             except:
#                 image = 'N/A'
#
#             # extract items
#             items = {
#                 'url': card.find('a', {'class': 'list-card-link'})['href'],
#                 'details': [
#                             price.text for price in
#                             card.find('ul', {'class': 'list-card-details'}).find_all('li')
#                           ],
#                 'address': card.find('address', {'class': 'list-card-addr'}).text,
#                 'image': image
#             }
#
#             # try to extract price if not extracted yet
#             try:
#                 items['price'] = card.find('div', {'class': 'list-card-price'}).text
#             except:
#                 pass
#
#             # append scraped items to results list
#             self.results.append(items)
#             print(json.dumps(items, indent=2))

# %%
import requests
from bs4 import BeautifulSoup
import csv
import json


class ZillowScraper:
    results = []

    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3',
        'accept-encoding': 'gzip, deflate, br',
        'accept-language': 'en-US,en;q=0.9',
        'cache-control': 'no-cache',
        'cookie': 'zguid=23|%2403435e76-0699-4a32-b86d-77d033c907ef; _ga=GA1.2.1271511001.1575011821; zjs_user_id=null; zjs_anonymous_id=%2203435e76-0699-4a32-b86d-77d033c907ef%22; _gcl_au=1.1.1333357279.1575011822; _pxvid=3cfcc163-1278-11ea-bff8-0242ac12000b; ki_r=; __gads=ID=84d8013cfac6df96:T=1575012041:S=ALNI_MaSvVNZsir2JXJ17pv54bjsPuyfcw; ki_s=199442%3A0.0.0.0.0%3B199444%3A0.0.0.0.2; zgsession=1|c0999376-b167-4a47-a1cd-0e456d882d4e; _gid=GA1.2.55965867.1578668946; JSESSIONID=87D0662A6BC141A73F0D12620788519C; KruxPixel=true; DoubleClickSession=true; KruxAddition=true; ki_t=1575011869563%3B1578669044158%3B1578669044158%3B2%3B10; _pxff_tm=1; _px3=2e6809e35ce7e076934ff998c2bdb8140e8b793b53e08a27c5da11f1b4760755:DFItCmrETuS2OQcztcFmt0FYPUn00ihAAue2ynQgbfSq6H+p2yP3Rl3aeyls3Unr1VRJSgcNue8Rr1SUq4P1jA==:1000:9ueZvAJ6v5y4ny7psGF25dK+d3GlytY2Bh+Xj9UUhC4DaioIZ+FMXPU0mOX+Qnghqut0jIT61gLecN4fyu6qXaPDlBX6YsZVbIry1YyBN/37l0Ri3JP+E0h+m+QEBB+bqb6MbE2HtgGBJRJAry8dgOKGM5JtBGdX+X/nuQX1xaw=; AWSALB=E6JYC43gXQRlE2jPT9e2vAQOYPvdHnccBlqi0mcXevYExTaHro0M+uo/Qxahi6JyLz9LpotY9eLtEbYrAOeQXcCm6UhjWnTopQHernmjlR/ibE6JmE8F6tReiBn4; search=6|1581261153229%7Crect%3D40.96202658306895%252C-73.55498286718745%252C40.4487909557045%252C-74.40093013281245%26rid%3D6181%26disp%3Dmap%26mdm%3Dauto%26p%3D3%26z%3D0%26lt%3Dfsbo%26pt%3Dpmf%252Cpf%26fs%3D1%26fr%3D0%26mmm%3D1%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%09%01%096181%09%09%09%090%09US_%09',
        'pragma': 'no-cache',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/75.0.3770.142 Chrome/75.0.3770.142 Safari/537.36'
    }

    def fetch(self, url, params):
        print('HTTP GET request to URL: %s' % url, end='')
        res = requests.get(url, params=params, headers=self.headers)
        print(' | Status code: %s' % res.status_code)
        
        return res
   
    def save_response(self, res):
        with open('res.html', 'w') as html_file:
            html_file.write(res)

    def load_response(self):
        html = ''
        
        with open('res.html', 'r') as html_file:
            for line in html_file:
                html += line
        
        return html
   
    def parse(self, html):
        # parse response
        content = BeautifulSoup(html, 'lxml')
        
        # extract property cards
        cards = content.findAll('article', {'class': 'list-card'})
        
        # extract coordinates script
        script = content.find('script', {'data-zrr-shared-data-key': 'mobileSearchPageStore'}).string

    
        # loop over property cards
        for card in cards:
            # try to extract image
            try:
                image = card.find('div', {'class': 'list-card-top'}).find('img')['src']
            except:
                image = 'N/A'
                
            # extract items
            items = {
                'url': card.find('a', {'class': 'list-card-link'})['href'],
                'details': [
                            price.text for price in
                            card.find('ul', {'class': 'list-card-details'}).find_all('li')
                          ],
                'address': card.find('address', {'class': 'list-card-addr'}).text,
                'image': image
            }
            
            # try to extract price if not extracted yet
            try:
                items['price'] = card.find('div', {'class': 'list-card-price'}).text

            except:
                pass
            
            # try to extract coordinates from script
            try:
                
                splitter = '"detailUrl":"' + items['url'] + '","latLong":'
               
                
                blah = script.split(splitter)
                blah2 = blah[-1]
                blah3 = blah2.split('},')
                blah4 = blah3[0]
                totalblah = blah4 + '}'
                
         
#                 print(blah2)
#                 print(blah3)
#                 print(blah4)                
#                 print(totalblah)


                coords = json.loads(script.split(splitter)[-1].split('},')[0] + '}')
                items['coordinates'] = coords
               
                print(coords)
                
            except:
                coords = script.split(splitter)[-1].split('},')[0] + '}'
                splitter = '<!--{"queryState":{"mapBounds":'
                
                try:
                    map_bounds = json.loads(coords.split(splitter)[-1])
                    items['coordinates'] = map_bounds
                except:
                     continue
            

            # append scraped items to results list
#             if items['coordinates'] == 'N/A':
#                 continue
                
            self.results.append(items)
            print(json.dumps(items, indent=2))
    
    def to_json(self):
        with open('zillow_rent.json', 'w') as f:
            f.write(json.dumps(self.results, indent=2))
        
    def run(self):
        for page in range(1, 5):
            params = {
                'searchQueryState': '{"pagination":{"currentPage":%s},"usersSearchTerm":"Chicago, IL","mapBounds":{"west":-88.09607811914063,"east":-87.36823388085938,"south":41.606969127843165,"north":42.060251786677156},"regionSelection":[{"regionId":17426,"regionType":6}],"isMapVisible":false,"filterState":{"pmf":{"value":false},"fore":{"value":false},"auc":{"value":false},"nc":{"value":false},"fr":{"value":true},"fsbo":{"value":false},"cmsn":{"value":false},"pf":{"value":false},"fsba":{"value":false}},"isListVisible":true}' % str(page)
            }
            res = self.fetch('https://www.zillow.com/homes/Chicago,-IL_rb/?', params)
            self.parse(res.text)

        self.to_json()
        
        #html = self.load_response()
        #self.parse(html)
        

if __name__ == '__main__':
    scraper = ZillowScraper()
    scraper.run()
# Out:
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {'latitude': 41.863776, 'longitude': -87.624547}
# {
#   "url": "https://www.zillow.com/b/1400-s-michigan-ave-chicago-il-CR3c/",
#   "details": [
#     "$1,900+ 1 bd",
#     "$2,600+ 2 bds"
#   ],
#   "address": "1400 S Michigan Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISf0t2y3bqeuow0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.863776,
#     "longitude": -87.624547
#   }
# }
# {'latitude': 41.884699, 'longitude': -87.616214}
# {
#   "url": "https://www.zillow.com/b/400-e-randolph-street-chicago-il-Dk6B/",
#   "details": [
#     "$1,475+ Studio",
#     "$1,450+ 1 bd",
#     "$2,600+ 2 bds"
#   ],
#   "address": "400 E Randolph Street | 400 E Randolph St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISbphvy85lahdx0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.884699,
#     "longitude": -87.616214
#   }
# }
# {'latitude': 41.881484, 'longitude': -87.625671}
# {
#   "url": "https://www.zillow.com/b/60-e-monroe-st-chicago-il-5XjDfM/",
#   "details": [
#     "$2,500+ 1 bd",
#     "$3,395+ 2 bds",
#     "$7,500+ 3 bds"
#   ],
#   "address": "60 E Monroe St, Chicago, IL",
#   "image": "N/A",
#   "coordinates": {
#     "latitude": 41.881484,
#     "longitude": -87.625671
#   }
# }
# {'latitude': 41.94738, 'longitude': -87.661413}
# {
#   "url": "https://www.zillow.com/b/3609-N-Lakewood-Ave-Chicago-IL/41.94738,-87.661413_ll/",
#   "details": [
#     "$2,995+ 3 bds",
#     "$3,395 4 bds"
#   ],
#   "address": "3609 N Lakewood Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.94738,
#     "longitude": -87.661413
#   }
# }
# {'latitude': 41.969358, 'longitude': -87.713202}
# {
#   "url": "https://www.zillow.com/b/4833-n-kimball-ave-chicago-il-9hKJ99/",
#   "details": [
#     "$950+ 1 bd"
#   ],
#   "address": "4833 N Kimball Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.969358,
#     "longitude": -87.713202
#   }
# }
# {'latitude': 41.917121, 'longitude': -87.68603}
# {
#   "url": "https://www.zillow.com/b/1961-n-wilmot-ave-chicago-il-5pgGkq/",
#   "details": [
#     "$2,000 2 bds",
#     "$2,700 3 bds"
#   ],
#   "address": "1961 N Wilmot Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.917121,
#     "longitude": -87.68603
#   }
# }
# {'latitude': 41.968224, 'longitude': -87.699546}
# {
#   "url": "https://www.zillow.com/b/4764-n-virginia-chicago-il-DpNN/",
#   "details": [
#     "$895 Studio",
#     "$1,068 1 bd"
#   ],
#   "address": "4764 N Virginia | 4764 N Virginia Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.968224,
#     "longitude": -87.699546
#   }
# }
# {'latitude': 41.815027, 'longitude': -87.620231}
# {
#   "url": "https://www.zillow.com/b/4348-58-prairie-ave-%26-218-24-44th-st-chicago-il-Bnr4wy/",
#   "details": [
#     "$1,565 1 bd",
#     "$1,595+ 2 bds",
#     "$2,195 3 bds"
#   ],
#   "address": "4348-58 Prairie Ave & 218-24 44th St | 4348 Prairie Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.815027,
#     "longitude": -87.620231
#   }
# }
# {'latitude': 41.842754, 'longitude': -87.616426}
# {
#   "url": "https://www.zillow.com/b/prairie-shores-chicago-il-5XfYSz/",
#   "details": [
#     "$820+ Studio",
#     "$1,193+ 1 bd",
#     "$1,355+ 2 bds",
#     "$2,313+ 3 bds"
#   ],
#   "address": "PRAIRIE SHORES | 2851 S King Dr, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.842754,
#     "longitude": -87.616426
#   }
# }
# {'latitude': 41.976543, 'longitude': -87.655348}
# {
#   "url": "https://www.zillow.com/b/the-edison-apartments-chicago-il-5XcBmv/",
#   "details": [
#     "$1,045+ Studio",
#     "$1,420+ 1 bd"
#   ],
#   "address": "The Edison Apartments | 5200 N Sheridan Rd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.976543,
#     "longitude": -87.655348
#   }
# }
# {'latitude': 41.888707, 'longitude': -87.646645}
# {
#   "url": "https://www.zillow.com/b/k2-apartments-chicago-il-5XkG63/",
#   "details": [
#     "$1,657+ Studio",
#     "$2,099+ 1 bd",
#     "$3,391 2 bds",
#     "$4,739 3 bds"
#   ],
#   "address": "K2 Apartments | 365 N Halsted St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.888707,
#     "longitude": -87.646645
#   }
# }
# {'latitude': 41.86405, 'longitude': -87.62691}
# {
#   "url": "https://www.zillow.com/b/1401-s.-state-chicago-il-5XjBBG/",
#   "details": [
#     "$1,645+ Studio",
#     "$1,712+ 1 bd",
#     "$2,505+ 2 bds"
#   ],
#   "address": "1401 S. State | 1401 S State St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.86405,
#     "longitude": -87.62691
#   }
# }
# {'latitude': 41.96149, 'longitude': -87.652376}
# {
#   "url": "https://www.zillow.com/b/the-montrose-chicago-il-5XgJnV/",
#   "details": [
#     "$1,260+ Studio",
#     "$1,660+ 1 bd",
#     "$2,065+ 2 bds"
#   ],
#   "address": "The Montrose | 4334 N Hazel St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.96149,
#     "longitude": -87.652376
#   }
# }
# {'latitude': 41.940721, 'longitude': -87.652336}
# {
#   "url": "https://www.zillow.com/b/3223-n-wilton-ave-chicago-il-5XgZ9c/",
#   "details": [
#     "$1,900 3 bds",
#     "$2,400 4 bds"
#   ],
#   "address": "3223 N Wilton Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.940721,
#     "longitude": -87.652336
#   }
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {'latitude': 41.891126, 'longitude': -87.621424}
# {
#   "url": "https://www.zillow.com/b/optima-signature-chicago-il-65bFNB/",
#   "details": [
#     "$2,045+ Studio",
#     "$2,660+ 1 bd",
#     "$3,250+ 2 bds",
#     "$5,770+ 3 bds"
#   ],
#   "address": "Optima Signature | 220 E Illinois St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS6idof5g622co1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.891126,
#     "longitude": -87.621424
#   }
# }
# {'latitude': 41.896213, 'longitude': -87.640749}
# {
#   "url": "https://www.zillow.com/b/the-hudson-chicago-il-9p4XvB/",
#   "details": [
#     "$2,100+ 1 bd",
#     "$2,665+ 2 bds",
#     "$8,700+ 3 bds"
#   ],
#   "address": "The Hudson | 750 N Hudson Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7qj6ghum3x0u0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.896213,
#     "longitude": -87.640749
#   }
# }
# {'latitude': 41.914923, 'longitude': -87.702794}
# {
#   "url": "https://www.zillow.com/b/1832-1842-north-humboldt-blvd-chicago-il-5XfQ6L/",
#   "details": [
#     "$1,595 1 bd",
#     "$1,845 2 bds",
#     "$1,995+ 3 bds"
#   ],
#   "address": "1832-1842 North Humboldt Blvd | 1832 N Humboldt Blvd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISv0kk75cwo7zq0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.914923,
#     "longitude": -87.702794
#   }
# }
# {'latitude': 41.885242, 'longitude': -87.646889}
# {
#   "url": "https://www.zillow.com/b/the-parker-chicago-il-65fxWg/",
#   "details": [
#     "$1,645+ Studio",
#     "$1,958+ 1 bd",
#     "$3,211+ 2 bds",
#     "$4,571+ 3 bds"
#   ],
#   "address": "The Parker | 730 W Couch Pl, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISzjd3e6ncpcqg1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.885242,
#     "longitude": -87.646889
#   }
# }
# {'latitude': 41.89407, 'longitude': -87.63517}
# {
#   "url": "https://www.zillow.com/b/flair-tower-chicago-il-5XjBzC/",
#   "details": [
#     "$1,835+ 1 bd",
#     "$3,120+ 2 bds",
#     "$5,460 3 bds"
#   ],
#   "address": "Flair Tower | 222 W Erie St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISf0xp2qiyyyv00000000000.jpg",
#   "coordinates": {
#     "latitude": 41.89407,
#     "longitude": -87.63517
#   }
# }
# {'latitude': 41.863853, 'longitude': -87.623607}
# {
#   "url": "https://www.zillow.com/b/landing%3a-monthly-leases,-designer-furnished,-%240-deposit-in-chicago-chicago-il-9Rwsts/",
#   "details": [
#     "$1,808+ Studio",
#     "$1,876+ 1 bd",
#     "$4,827 2 bds"
#   ],
#   "address": "Landing: Monthly Leases, Designer Furnished, $0 Deposit in Chicago | 1407 S Michigan Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.863853,
#     "longitude": -87.623607
#   }
# }
# {'latitude': 41.892206, 'longitude': -87.619746}
# {
#   "url": "https://www.zillow.com/b/landing%3a-monthly-leases-in-chicago,-designer-furnished,-%240-deposit-chicago-il-9Ry34s/",
#   "details": [
#     "$1,808+ Studio",
#     "$1,876+ 1 bd",
#     "$4,827 2 bds"
#   ],
#   "address": "Landing: Monthly Leases in Chicago, Designer Furnished, $0 Deposit | 541 N Fairbanks Ct, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.892206,
#     "longitude": -87.619746
#   }
# }
# {'latitude': 41.879781, 'longitude': -87.626551}
# {
#   "url": "https://www.zillow.com/b/the-alfred-chicago-il-F3kF/",
#   "details": [
#     "$1,890+ Studio",
#     "$1,710+ 1 bd",
#     "$3,000+ 2 bds"
#   ],
#   "address": "The Alfred | 30 E Adams St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.879781,
#     "longitude": -87.626551
#   }
# }
# {'latitude': 41.896764, 'longitude': -87.631901}
# {
#   "url": "https://www.zillow.com/b/the-bush-temple-chicago-il-9qwkQ9/",
#   "details": [
#     "$1,450+ Studio",
#     "$1,700+ 1 bd",
#     "$3,100+ 2 bds"
#   ],
#   "address": "The Bush Temple | 108 W Chicago Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.896764,
#     "longitude": -87.631901
#   }
# }
# {'latitude': 41.937367, 'longitude': -87.641492}
# {
#   "url": "https://www.zillow.com/b/445-w-barry-chicago-il-5XgGR6/",
#   "details": [
#     "$1,075+ Studio",
#     "$1,375+ 1 bd"
#   ],
#   "address": "445 W Barry | 445 W Barry Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.937367,
#     "longitude": -87.641492
#   }
# }
# {'latitude': 41.896038, 'longitude': -87.651032}
# {
#   "url": "https://www.zillow.com/b/germain-house-chicago-il-9S4pdF/",
#   "details": [
#     "$1,840 Studio",
#     "$2,030+ 1 bd",
#     "$2,828 2 bds"
#   ],
#   "address": "Germain House | 925 W Chicago Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.896038,
#     "longitude": -87.651032
#   }
# }
# {'latitude': 41.871059, 'longitude': -87.624736}
# {
#   "url": "https://www.zillow.com/b/820-s-michigan-ave-chicago-il-F89z/",
#   "details": [
#     "$1,295+ Studio",
#     "$1,695+ 1 bd",
#     "$1,945+ 2 bds"
#   ],
#   "address": "820 S Michigan Ave | 820 S Michigan Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.871059,
#     "longitude": -87.624736
#   }
# }
# {'latitude': 41.894794, 'longitude': -87.652654}
# {
#   "url": "https://www.zillow.com/b/713-n-milwaukee-ave-chicago-il-65cSHR/",
#   "details": [
#     "$2,050+ 1 bd",
#     "$2,425+ 2 bds"
#   ],
#   "address": "713 N Milwaukee Ave | 713 N Milwaukee Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.894794,
#     "longitude": -87.652654
#   }
# }
# {'latitude': 41.941581, 'longitude': -87.639073}
# {
#   "url": "https://www.zillow.com/b/3260-%26-3270-n-lake-shore-drive-chicago-il-BhNccM/",
#   "details": [
#     "$1,660+ 1 bd",
#     "$3,715+ 3 bds"
#   ],
#   "address": "3260 & 3270 N Lake Shore Drive | 3260 & 3270 N Lake Shore Dr N, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.941581,
#     "longitude": -87.639073
#   }
# }
# {'latitude': 41.895117, 'longitude': -87.653629}
# {
#   "url": "https://www.zillow.com/b/avenir-chicago-il-BZ3D2d/",
#   "details": [
#     "$1,690+ Studio",
#     "$1,985+ 1 bd",
#     "$3,695+ 2 bds",
#     "$3,785+ 3 bds"
#   ],
#   "address": "Avenir | 730 N Milwaukee Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.895117,
#     "longitude": -87.653629
#   }
# }
# {'latitude': 41.936287, 'longitude': -87.639813}
# {
#   "url": "https://www.zillow.com/b/2970-n-sheridan-chicago-il-5Xdjyg/",
#   "details": [
#     "$985+ Studio",
#     "$1,390+ 1 bd"
#   ],
#   "address": "2970 N Sheridan | 2970 N Sheridan Rd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.936287,
#     "longitude": -87.639813
#   }
# }
# {'latitude': 41.903738, 'longitude': -87.630423}
# {
#   "url": "https://www.zillow.com/b/1164-north-dearborn-street-chicago-il-5Xck78/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,765+ 1 bd"
#   ],
#   "address": "1164 North Dearborn Street | 1164 N Dearborn St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.903738,
#     "longitude": -87.630423
#   }
# }
# {'latitude': 41.872541, 'longitude': -87.628366}
# {
#   "url": "https://www.zillow.com/b/731-s-plymouth-chicago-il-Crzp/",
#   "details": [
#     "$1,599+ 1 bd",
#     "$1,799+ 2 bds",
#     "$2,795+ 3 bds"
#   ],
#   "address": "731 S Plymouth | 731 S Plymouth Ct, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.872541,
#     "longitude": -87.628366
#   }
# }
# {'latitude': 41.936882, 'longitude': -87.63984}
# {
#   "url": "https://www.zillow.com/b/3000-n-sheridan-chicago-il-5XgZXW/",
#   "details": [
#     "$3,070 2 bds",
#     "$3,550+ 3 bds",
#     "$3,845 4 bds"
#   ],
#   "address": "3000 N Sheridan | 3000 N Sheridan Rd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.936882,
#     "longitude": -87.63984
#   }
# }
# {'latitude': 41.941318, 'longitude': -87.641146}
# {
#   "url": "https://www.zillow.com/b/450-west-melrose-chicago-il-5XgZHM/",
#   "details": [
#     "$1,011+ Studio",
#     "$1,319+ 1 bd"
#   ],
#   "address": "450 West Melrose | 450 W Melrose St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.941318,
#     "longitude": -87.641146
#   }
# }
# {'latitude': 41.908936, 'longitude': -87.650021}
# {
#   "url": "https://www.zillow.com/b/sono-east-chicago-il-BW3V/",
#   "details": [
#     "$1,778 Studio",
#     "$1,711+ 1 bd",
#     "$3,274+ 2 bds"
#   ],
#   "address": "SoNo East | 840 W Blackhawk St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.908936,
#     "longitude": -87.650021
#   }
# }
# {'latitude': 41.801778, 'longitude': -87.585067}
# {
#   "url": "https://www.zillow.com/b/5120-s.-hyde-park-boulevard-chicago-il-5XcW7W/",
#   "details": [
#     "$1,055+ Studio"
#   ],
#   "address": "5120 S. Hyde Park Boulevard | 5120 S Hyde Park Blvd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.801778,
#     "longitude": -87.585067
#   }
# }
# {'latitude': 41.897955, 'longitude': -87.619915}
# {
#   "url": "https://www.zillow.com/b/244-e.-pearson-chicago-il-9Rxr3w/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,695+ 1 bd"
#   ],
#   "address": "244 E. Pearson | 244 E Pearson St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.897955,
#     "longitude": -87.619915
#   }
# }
# {'latitude': 41.882287, 'longitude': -87.654722}
# {
#   "url": "https://www.zillow.com/b/the-aberdeen-west-loop-chicago-il-5ZgrJT/",
#   "details": [
#     "$2,495 1 bd",
#     "$2,895+ 2 bds"
#   ],
#   "address": "The Aberdeen West Loop | 20 N Aberdeen St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.882287,
#     "longitude": -87.654722
#   }
# }
# {'latitude': 41.906744, 'longitude': -87.630493}
# {
#   "url": "https://www.zillow.com/b/1330-n-dearborn-chicago-il-5XhGwj/",
#   "details": [
#     "$1,360+ Studio",
#     "$1,410+ 1 bd"
#   ],
#   "address": "1330 N Dearborn | 1330 N Dearborn St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.906744,
#     "longitude": -87.630493
#   }
# }
# {'latitude': 41.906156, 'longitude': -87.677524}
# {
#   "url": "https://www.zillow.com/b/1336-n-damen-chicago-il-5hGVdZ/",
#   "details": [
#     "$2,400 2 bds",
#     "$3,750 3 bds"
#   ],
#   "address": "1336 N Damen | 1336 N Damen Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.906156,
#     "longitude": -87.677524
#   }
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {'latitude': 41.917924, 'longitude': -87.662905}
# {
#   "url": "https://www.zillow.com/b/southport-lofts-chicago-il-DCFv/",
#   "details": [
#     "$1,536+ Studio",
#     "$1,924+ 1 bd",
#     "$2,972+ 2 bds"
#   ],
#   "address": "Southport Lofts | 2061 N Southport Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7a7aermzgjwc1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.917924,
#     "longitude": -87.662905
#   }
# }
# {'latitude': 41.885308, 'longitude': -87.624165}
# {
#   "url": "https://www.zillow.com/b/millennium-park-plaza-chicago-il-9bmb/",
#   "details": [
#     "$1,515+ Studio",
#     "$1,645+ 1 bd",
#     "$2,365+ 2 bds",
#     "$3,115+ 3 bds"
#   ],
#   "address": "Millennium Park Plaza | 151 N Michigan Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISrtrqmqzl6f9b1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.885308,
#     "longitude": -87.624165
#   }
# }
# {'latitude': 41.882148, 'longitude': -87.66724}
# {
#   "url": "https://www.zillow.com/b/warren-chicago-il-63dtBL/",
#   "details": [
#     "$2,250+ 2 bds"
#   ],
#   "address": "Warren | 1609 W Warren Blvd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISz74cd46x3dpt0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.882148,
#     "longitude": -87.66724
#   }
# }
# {'latitude': 41.892863, 'longitude': -87.616655}
# {
#   "url": "https://www.zillow.com/b/420-e-ohio-chicago-il-5XdDLs/",
#   "details": [
#     "$1,499+ Studio",
#     "$2,276+ 1 bd",
#     "$2,885+ 2 bds",
#     "$3,867+ 3 bds"
#   ],
#   "address": "420 E Ohio | 420 E Ohio St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISzno2gd3yg0k71000000000.jpg",
#   "coordinates": {
#     "latitude": 41.892863,
#     "longitude": -87.616655
#   }
# }
# {'latitude': 41.948927, 'longitude': -87.646785}
# {
#   "url": "https://www.zillow.com/b/612-west-patterson-avenue-chicago-il-5XhJG5/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,395+ 1 bd"
#   ],
#   "address": "612 West Patterson Avenue | 612 W Patterson Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISvw8llqsdfn3g1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.948927,
#     "longitude": -87.646785
#   }
# }
# {'latitude': 41.922096, 'longitude': -87.695725}
# {
#   "url": "https://www.zillow.com/b/mica-chicago-il-9nbRQR/",
#   "details": [
#     "$1,995+ 1 bd",
#     "$2,695 2 bds",
#     "$3,395+ 3 bds"
#   ],
#   "address": "MiCA | 2210 N Washtenaw Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISjju3wwaypev21000000000.jpg",
#   "coordinates": {
#     "latitude": 41.922096,
#     "longitude": -87.695725
#   }
# }
# {'latitude': 41.964859, 'longitude': -87.654593}
# {
#   "url": "https://www.zillow.com/b/upshore-chapter-chicago-il-BPtGcx/",
#   "details": [
#     "$1,288+ Studio",
#     "$1,377+ 1 bd",
#     "$2,376 2 bds"
#   ],
#   "address": "Upshore Chapter | 4555 N Sheridan Rd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISf8jc9yuzwaow0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.964859,
#     "longitude": -87.654593
#   }
# }
# {'latitude': 41.877918, 'longitude': -87.657625}
# {
#   "url": "https://www.zillow.com/b/the-jax-chicago-il-BK9z84/",
#   "details": [
#     "$1,473+ Studio",
#     "$1,805+ 1 bd",
#     "$3,415+ 2 bds"
#   ],
#   "address": "The Jax | 1220 W Jackson Blvd, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISrhmat03at0tx1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.877918,
#     "longitude": -87.657625
#   }
# }
# {'latitude': 41.915262, 'longitude': -87.698466}
# {
#   "url": "https://www.zillow.com/b/1846-N-Mozart-St-Chicago-IL/41.915262,-87.698466_ll/",
#   "details": [
#     "$1,700+ 2 bds"
#   ],
#   "address": "1846 N Mozart St, Chicago, IL",
#   "image": "N/A",
#   "coordinates": {
#     "latitude": 41.915262,
#     "longitude": -87.698466
#   }
# }
# {'latitude': 41.968968, 'longitude': -87.683593}
# {
#   "url": "https://www.zillow.com/b/2150-w-lawrence-avenue-chicago-il-CqgP/",
#   "details": [
#     "$1,895+ 1 bd",
#     "$2,495+ 2 bds"
#   ],
#   "address": "2150 W Lawrence Avenue | 2150 W Lawrence Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.968968,
#     "longitude": -87.683593
#   }
# }
# {'latitude': 41.813308, 'longitude': -87.614831}
# {
#   "url": "https://www.zillow.com/b/438-45th-pl-chicago-il-BpjWq6/",
#   "details": [
#     "$1,895+ 3 bds"
#   ],
#   "address": "438 45th Pl | 438 45th Pl, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.813308,
#     "longitude": -87.614831
#   }
# }
# {'latitude': 41.882026, 'longitude': -87.663307}
# {
#   "url": "https://www.zillow.com/b/15-25-n-bishop-chicago-il-5XfX68/",
#   "details": [
#     "$3,675+ 3 bds"
#   ],
#   "address": "15-25 N Bishop | 15 N Bishop St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.882026,
#     "longitude": -87.663307
#   }
# }
# {'latitude': 41.891391, 'longitude': -87.646351}
# {
#   "url": "https://www.zillow.com/b/seven-10-west-chicago-il-9S69wd/",
#   "details": [
#     "$1,695+ 1 bd",
#     "$2,595+ 2 bds"
#   ],
#   "address": "Seven 10 West | 710 W Grand Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.891391,
#     "longitude": -87.646351
#   }
# }
# {'latitude': 41.990774, 'longitude': -87.657212}
# {
#   "url": "https://www.zillow.com/b/5958-n-kenmore-av-chicago-il-CC6x/",
#   "details": [
#     "$945+ Studio",
#     "$1,215 1 bd"
#   ],
#   "address": "5958 N Kenmore Av | 5958 N Kenmore Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.990774,
#     "longitude": -87.657212
#   }
# }
# {'latitude': 41.930168, 'longitude': -87.642053}
# {
#   "url": "https://www.zillow.com/b/515-wrightwood-condominiums-chicago-il-Drw8/",
#   "details": [
#     "$1,200+ Studio",
#     "$1,275+ 1 bd"
#   ],
#   "address": "515 Wrightwood Condominiums | 515 W Wrightwood Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.930168,
#     "longitude": -87.642053
#   }
# }
# {'latitude': 41.92802, 'longitude': -87.709698}
# {
#   "url": "https://www.zillow.com/b/3257-3267-w.-wrightwood-ave-chicago-il-BM9Hk6/",
#   "details": [
#     "$965+ Studio",
#     "$1,395+ 1 bd"
#   ],
#   "address": "3257 - 3267 W. Wrightwood Ave | 3257-3267 W Wrightwood Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.92802,
#     "longitude": -87.709698
#   }
# }
# {'latitude': 41.905396, 'longitude': -87.634173}
# {
#   "url": "https://www.zillow.com/b/1225-old-town-chicago-il-CQpR/",
#   "details": [
#     "$1,870+ Studio",
#     "$2,337+ 1 bd",
#     "$3,373+ 2 bds",
#     "$4,809 3 bds"
#   ],
#   "address": "1225 Old Town | 1225 N Wells St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.905396,
#     "longitude": -87.634173
#   }
# }
# {'latitude': 41.956584, 'longitude': -87.656538}
# {
#   "url": "https://www.zillow.com/b/4070-n.-kenmore-chicago-il-9RyL9j/",
#   "details": [
#     "$975+ Studio"
#   ],
#   "address": "4070 N. Kenmore | 4070 N Kenmore Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.956584,
#     "longitude": -87.656538
#   }
# }
# {'latitude': 41.929058, 'longitude': -87.643767}
# {
#   "url": "https://www.zillow.com/b/625-w-wrightwood-chicago-il-C65B/",
#   "details": [
#     "$1,325+ Studio",
#     "$1,625+ 1 bd"
#   ],
#   "address": "625 W Wrightwood | 625 W Wrightwood Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.929058,
#     "longitude": -87.643767
#   }
# }
# {'latitude': 41.965546, 'longitude': -87.664313}
# {
#   "url": "https://www.zillow.com/b/4600-4608-n.-beacon-chicago-il-9hJDLg/",
#   "details": [
#     "$850+ Studio"
#   ],
#   "address": "4600 - 4608 N. Beacon | 4600-4608 N Beacon St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.965546,
#     "longitude": -87.664313
#   }
# }
# {'latitude': 41.71575, 'longitude': -87.599404}
# {
#   "url": "https://www.zillow.com/b/4721-s.-ellis-avenue-chicago-il-Bh9wgM/",
#   "details": [
#     "$875+ Studio",
#     "$1,085+ 1 bd",
#     "$1,225+ 2 bds"
#   ],
#   "address": "4721 S. Ellis Avenue | 4721-29 S Ellis Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.71575,
#     "longitude": -87.599404
#   }
# }
# {'latitude': 42.011449, 'longitude': -87.664415}
# {
#   "url": "https://www.zillow.com/b/1331-w.-estes-chicago-il-9YTZ/",
#   "details": [
#     "$945+ Studio",
#     "$1,095+ 1 bd"
#   ],
#   "address": "1331 W. Estes | 1331 W Estes Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 42.011449,
#     "longitude": -87.664415
#   }
# }
# {'latitude': 41.92376, 'longitude': -87.692357}
# {
#   "url": "https://www.zillow.com/b/2317-27-north-rockwell-street-chicago-il-9S5Pm6/",
#   "details": [
#     "$1,325+ Studio",
#     "$1,595+ 1 bd",
#     "$1,950+ 2 bds"
#   ],
#   "address": "2317-27 North Rockwell Street | 2317 N Rockwell St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.92376,
#     "longitude": -87.692357
#   }
# }
# {'latitude': 41.932499, 'longitude': -87.641584}
# {
#   "url": "https://www.zillow.com/b/2756-n-pine-grove-chicago-il-5Xg3d2/",
#   "details": [
#     "$1,447+ 1 bd",
#     "$1,949+ 2 bds"
#   ],
#   "address": "2756 N Pine Grove | 2756 N Pine Grove Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.932499,
#     "longitude": -87.641584
#   }
# }
# {'latitude': 42.019185, 'longitude': -87.669543}
# {
#   "url": "https://www.zillow.com/b/elevation-lofts-chicago-il-BMwvfR/",
#   "details": [
#     "$1,625+ 2 bds",
#     "$3,000+ 3 bds"
#   ],
#   "address": "Elevation Lofts | 1531 W Howard St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 42.019185,
#     "longitude": -87.669543
#   }
# }
# {'latitude': 41.895109, 'longitude': -87.627623}
# {
#   "url": "https://www.zillow.com/b/residences-at-8-east-huron-chicago-il-9Ry5bB/",
#   "details": [
#     "$2,097+ 1 bd",
#     "$3,948+ 2 bds"
#   ],
#   "address": "Residences at 8 East Huron | 8 E Huron St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.895109,
#     "longitude": -87.627623
#   }
# }
# {'latitude': 41.881431, 'longitude': -87.648971}
# {
#   "url": "https://www.zillow.com/b/727-west-madison-chicago-il-BCgw9T/",
#   "details": [
#     "$1,800+ Studio",
#     "$2,540+ 1 bd",
#     "$3,580+ 2 bds",
#     "$5,620+ 3 bds"
#   ],
#   "address": "727 West Madison | 727 W Madison St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.881431,
#     "longitude": -87.648971
#   }
# }
# {'latitude': 41.947844, 'longitude': -87.646241}
# {
#   "url": "https://www.zillow.com/b/632-west-addison-chicago-il-5XcZFX/",
#   "details": [
#     "$1,052+ Studio",
#     "$1,293+ 1 bd",
#     "$2,000+ 2 bds"
#   ],
#   "address": "632 West Addison | 632 W Addison St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.947844,
#     "longitude": -87.646241
#   }
# }
# {'latitude': 41.886609, 'longitude': -87.631385}
# {
#   "url": "https://www.zillow.com/b/OneEleven-Chicago-IL/41.886609,-87.631385_ll/",
#   "details": [
#     "$1,850+ Studio",
#     "$2,260+ 1 bd",
#     "$3,486+ 2 bds",
#     "$4,840+ 3 bds"
#   ],
#   "address": "OneEleven | 111 W Wacker Dr, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.886609,
#     "longitude": -87.631385
#   }
# }
# {'latitude': 41.854301, 'longitude': -87.625003}
# {
#   "url": "https://www.zillow.com/b/61-e-21st-st-chicago-il-B36RT3/",
#   "details": [
#     "$1,150+ Studio",
#     "$1,325+ 1 bd",
#     "$1,999+ 2 bds"
#   ],
#   "address": "61 E 21st St | 61 E 21st St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.854301,
#     "longitude": -87.625003
#   }
# }
# HTTP GET request to URL: https://www.zillow.com/homes/Chicago,-IL_rb/? | Status code: 200
# {'latitude': 41.854301, 'longitude': -87.625003}
# {
#   "url": "https://www.zillow.com/b/61-e-21st-st-chicago-il-B36RT3/",
#   "details": [
#     "$1,150+ Studio",
#     "$1,325+ 1 bd",
#     "$1,999+ 2 bds"
#   ],
#   "address": "61 E 21st St | 61 E 21st St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISfk06pn4q3fn81000000000.jpg",
#   "coordinates": {
#     "latitude": 41.854301,
#     "longitude": -87.625003
#   }
# }
# {'latitude': 41.898208, 'longitude': -87.631745}
# {
#   "url": "https://www.zillow.com/b/100-west-chestnut-chicago-il-5Xj9Gt/",
#   "details": [
#     "$1,415+ 1 bd",
#     "$2,082+ 2 bds"
#   ],
#   "address": "100 West Chestnut | 100 W Chestnut St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISvwcoartx4mcz0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.898208,
#     "longitude": -87.631745
#   }
# }
# {'latitude': 41.907522, 'longitude': -87.634925}
# {
#   "url": "https://www.zillow.com/b/cobbler-square-lofts-chicago-il-5XfPr9/",
#   "details": [
#     "$1,410+ Studio",
#     "$1,880+ 1 bd",
#     "$2,680+ 2 bds"
#   ],
#   "address": "Cobbler Square Lofts | 1350 N Wells St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISbxbozurvmotj1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.907522,
#     "longitude": -87.634925
#   }
# }
# {'latitude': 41.888891, 'longitude': -87.62643}
# {
#   "url": "https://www.zillow.com/b/401-n-wabash-avenue-chicago-il-5XfQCx/",
#   "details": [
#     "$3,000+ 1 bd"
#   ],
#   "address": "401 N Wabash Avenue | 401 N Wabash Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISfkcr9rxa330a1000000000.jpg",
#   "coordinates": {
#     "latitude": 41.888891,
#     "longitude": -87.62643
#   }
# }
# {'latitude': 41.945979, 'longitude': -87.643529}
# {
#   "url": "https://www.zillow.com/b/cornelia-%26-stratford-chicago-il-Cr4s/",
#   "details": [
#     "$990+ Studio",
#     "$1,480+ 1 bd",
#     "$3,995 3 bds",
#     "$3,975+ 4 bds"
#   ],
#   "address": "Cornelia & Stratford | 535 W Cornelia Ave, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/IS7qvvbgehcjgu0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.945979,
#     "longitude": -87.643529
#   }
# }
# {'latitude': 41.906575, 'longitude': -87.634131}
# {
#   "url": "https://www.zillow.com/b/1325-n.-wells-chicago-il-9RxcDL/",
#   "details": [
#     "$2,300+ 1 bd",
#     "$2,780+ 2 bds"
#   ],
#   "address": "1325 N. Wells | 1325 N Wells St, Chicago, IL",
#   "image": "https://photos.zillowstatic.com/p_e/ISb9x0tav77m0p0000000000.jpg",
#   "coordinates": {
#     "latitude": 41.906575,
#     "longitude": -87.634131
#   }
# }
# {'latitude': 41.894007, 'longitude': -87.621451}
# {
#   "url": "https://www.zillow.com/b/233-e-erie-st-chicago-il-5XjDWv/",
#   "details": [
#     "$1,475+ Studio",
#     "$1,466+ 1 bd"
#   ],
#   "address": "233 E Erie St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.894007,
#     "longitude": -87.621451
#   }
# }
# {'latitude': 41.902937, 'longitude': -87.676035}
# {
#   "url": "https://www.zillow.com/b/1935-w-division-st-chicago-il-9S24Jm/",
#   "details": [
#     "$1,500+ 2 bds"
#   ],
#   "address": "1935 W Division St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.902937,
#     "longitude": -87.676035
#   }
# }
# {'latitude': 41.925421, 'longitude': -87.667545}
# {
#   "url": "https://www.zillow.com/b/fullerton-chicago-il-64kb96/",
#   "details": [
#     "$2,200+ 2 bds",
#     "$2,800+ 3 bds"
#   ],
#   "address": "Fullerton | 1540 W Fullerton Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.925421,
#     "longitude": -87.667545
#   }
# }
# {'latitude': 41.903513, 'longitude': -87.627954}
# {
#   "url": "https://www.zillow.com/b/18-e.-elm-chicago-il-5XcSsd/",
#   "details": [
#     "$1,095+ Studio",
#     "$1,375+ 1 bd",
#     "$2,285+ 2 bds"
#   ],
#   "address": "18 E. Elm | 18 E Elm St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.903513,
#     "longitude": -87.627954
#   }
# }
# {'latitude': 41.750914, 'longitude': -87.602559}
# {
#   "url": "https://www.zillow.com/b/7917-27-s-drexel-ave-chicago-il-9h8Bqt/",
#   "details": [
#     "$730+ 1 bd",
#     "$800+ 2 bds"
#   ],
#   "address": "7917-27 S Drexel Ave | 7917-27 S Drexel Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.750914,
#     "longitude": -87.602559
#   }
# }
# {'latitude': 41.809855, 'longitude': -87.603333}
# {
#   "url": "https://www.zillow.com/b/the-sutherland-chicago-il-5XmM62/",
#   "details": [
#     "$1,150+ Studio",
#     "$1,472+ 1 bd",
#     "$1,683+ 2 bds"
#   ],
#   "address": "The Sutherland | 4659 S Drexel Blvd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.809855,
#     "longitude": -87.603333
#   }
# }
# {'latitude': 41.903464, 'longitude': -87.644262}
# {
#   "url": "https://www.zillow.com/b/xavier-chicago-il-5q4SqT/",
#   "details": [
#     "$1,700+ Studio",
#     "$2,089+ 1 bd",
#     "$2,850+ 2 bds"
#   ],
#   "address": "Xavier | 625 W Division St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.903464,
#     "longitude": -87.644262
#   }
# }
# {'latitude': 41.799338, 'longitude': -87.584469}
# {
#   "url": "https://www.zillow.com/b/5300-5308-s.-hyde-park-boulevard-chicago-il-9ggKFq/",
#   "details": [
#     "$979+ Studio",
#     "$1,240+ 1 bd",
#     "$1,425+ 2 bds"
#   ],
#   "address": "5300-5308 S. Hyde Park Boulevard | 5300-5308 S Hyde Park Blvd, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.799338,
#     "longitude": -87.584469
#   }
# }
# {'latitude': 42.01493, 'longitude': -87.66389}
# {
#   "url": "https://www.zillow.com/b/1209-w-sherwin-chicago-il-BB4F/",
#   "details": [
#     "$775+ Studio",
#     "$1,050 1 bd"
#   ],
#   "address": "1209 W Sherwin | 1209 W Sherwin Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 42.01493,
#     "longitude": -87.66389
#   }
# }
# {'latitude': 41.93463, 'longitude': -87.651684}
# {
#   "url": "https://www.zillow.com/b/2900-north-mildred-avenue-chicago-il-CQqB/",
#   "details": [
#     "$1,395+ Studio",
#     "$1,595+ 1 bd"
#   ],
#   "address": "2900 North Mildred Avenue | 2900 N Mildred Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.93463,
#     "longitude": -87.651684
#   }
# }
# {'latitude': 41.885059, 'longitude': -87.643715}
# {
#   "url": "https://www.zillow.com/b/emme-chicago-chicago-il-BFG6rV/",
#   "details": [
#     "$1,750+ Studio",
#     "$2,050+ 1 bd",
#     "$3,134+ 2 bds"
#   ],
#   "address": "Emme Chicago | 165 N Desplaines St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.885059,
#     "longitude": -87.643715
#   }
# }
# {'latitude': 41.898023, 'longitude': -87.637455}
# {
#   "url": "https://www.zillow.com/b/next-apartments-chicago-il-65gycw/",
#   "details": [
#     "$1,583+ Studio",
#     "$2,276+ 1 bd",
#     "$3,022+ 2 bds",
#     "$5,910+ 3 bds"
#   ],
#   "address": "NEXT Apartments | 347 W Chestnut St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.898023,
#     "longitude": -87.637455
#   }
# }
# {'latitude': 41.802271, 'longitude': -87.588963}
# {
#   "url": "https://www.zillow.com/b/city-hyde-park-chicago-il-65cp2d/",
#   "details": [
#     "$2,175+ 1 bd",
#     "$2,575+ 2 bds",
#     "$3,150+ 3 bds"
#   ],
#   "address": "City Hyde Park | 5105 S Harper Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.802271,
#     "longitude": -87.588963
#   }
# }
# {'latitude': 41.801798, 'longitude': -87.603801}
# {
#   "url": "https://www.zillow.com/b/drexel-terrace-chicago-il-5Xfb8G/",
#   "details": [
#     "$1,085+ 1 bd"
#   ],
#   "address": "Drexel Terrace | 5043 S Drexel Ave, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.801798,
#     "longitude": -87.603801
#   }
# }
# {'latitude': 41.89142, 'longitude': -87.649056}
# {
#   "url": "https://www.zillow.com/b/reside-on-green-street-chicago-il-65hP6n/",
#   "details": [
#     "$1,718+ Studio",
#     "$2,035+ 1 bd",
#     "$3,229+ 2 bds",
#     "$5,150+ 3 bds"
#   ],
#   "address": "Reside on Green Street | 504 N Green St, Chicago, IL",
#   "image": "...",
#   "coordinates": {
#     "latitude": 41.89142,
#     "longitude": -87.649056
#   }
# }

# %%
import pandas as pd
pd.read_json

# %% [markdown]
# from googlegeocoder import GoogleGeocoder
# geocoder = GoogleGeocoder()
# list_of_addresses = [
#     '1727 E 107th St, Los Angeles, CA',
#     '317 Broadway, Los Angeles, CA'
# ]
#
# key=AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8
#
# for address in list_of_addresses:
#     try:
#         search = geocoder.get(address)
#     except ValueError:
#         continue
#     first_result = search[0]
#     output =  [
#         first_result.formatted_address,
#         first_result.geometry.location.lat,
#         first_result.geometry.location.lng,
#         first_result.geometry.location_type
#     ]
#     print(str, output)

# %% [markdown]
# import requests
#
# URL = "https://geocode.search.hereapi.com/v1/geocode"
# location = input("Enter the location here: ") #taking user input
# api_key = 'AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8' # Acquire from developer.here.com
# PARAMS = {'apikey':api_key,'q':location}
#
# # sending get request and saving the response as response object
# r = requests.get(url = URL, params = PARAMS)
# data = r.json()
#
# latitude = data['items'][0]['position']['lat']
# longitude = data['items'][0]['position']['lng']

# %% [markdown]
# # API KEY: AIzaSyBl5IS1_Ln1HiWDqEbaw2z2aKbfMSnZsT8

# %% [markdown]
# from geopy.geocoders import Nominatim
# geolocator = Nominatim(user_agent="geoapiExercises")
# ladd1 = "27488 Stanford Avenue, North Dakota"
# print("Location address:",ladd1)
# location = geolocator.geocode(ladd1)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
# ladd2 = "380 New York St, Redlands, CA 92373"
# print("\nLocation address:",ladd2)
# location = geolocator.geocode(ladd2)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
# ladd3 = "1600 Pennsylvania Avenue NW"
# print("\nLocation address:",ladd3)
# location = geolocator.geocode(ladd3)
# print("Latitude and Longitude of the said address:")
# print((location.latitude, location.longitude))
